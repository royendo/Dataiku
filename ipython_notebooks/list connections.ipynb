# %%
# %pylab inline

# %%
import dataiku
import prettyprinter

client = dataiku.api_client()
dss_connections = client.list_connections()
prettyprinter.pprint(dss_connections)

# %%
# Out:
# {
#     'filesystem_managed': {
#         'params': {
#             'root': '${dip.home}/managed_datasets',
#             'forcePathsOnDatasetsImport': True,
#             'dkuProperties': [],
#             'namingRule': {}
#         },
#         'name': 'filesystem_managed',
#         'type': 'Filesystem',
#         'allowWrite': True,
#         'allowManagedDatasets': True,
#         'allowManagedFolders': False,
#         'useGlobalProxy': True,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     },
#     'snowflake': {
#         'params': {
#             'authType': 'PASSWORD',
#             'driverMode': 'MANAGED',
#             'warehouse': 'WAREHOUSE1',
#             'useSparkNativeIntegration': False,
#             'useJavaUDF': False,
#             'useAutoFastPath': False,
#             'host': 'dh38956.snowflakecomputing.com',
#             'user': 'integration_tests',
#             'password':
#                 'e:AES:X2:'
#                 'Ma8NgBHlzpCrgyaW8Vu7XQRR7kUD2Bd0ujHyjK8KVz8jR8gjQ2arQ6QChUUEi9iVz'
#                 '6IxYUF8l5pcf2ZI',
#             'db': 'INTEGRATION_TESTS',
#             'useURL': False,
#             'namingRule': {
#                 'tableNameDatasetNamePrefix': '${projectKey}_',
#                 'canOverrideCatalogInManagedDatasetCreation': False,
#                 'canOverrideSchemaInManagedDatasetCreation': False
#             },
#             'useTruncate': False,
#             'autocommitMode': False,
#             'properties': [],
#             'dkuProperties': [],
#             'useAsMetastoreSource': False,
#             'metastoreSourceType': 'SPARKSQL_THRIFT'
#         },
#         'name': 'snowflake',
#         'type': 'Snowflake',
#         'creationTag': {
#             'versionNumber': 0,
#             'lastModifiedBy': {'login': 'admin'},
#             'lastModifiedOn': 1652171251451
#         },
#         'allowWrite': True,
#         'allowManagedDatasets': True,
#         'allowManagedFolders': False,
#         'useGlobalProxy': False,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     },
#     'filesystem_folders': {
#         'params': {
#             'root': '${dip.home}/managed_folders/${TEST}',
#             'forcePathsOnDatasetsImport': True,
#             'dkuProperties': [],
#             'namingRule': {'pathDatasetNamePrefix': ''}
#         },
#         'name': 'filesystem_folders',
#         'type': 'Filesystem',
#         'allowWrite': True,
#         'allowManagedDatasets': False,
#         'allowManagedFolders': True,
#         'useGlobalProxy': True,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     },
#     'filesystem_root': {
#         'params': {
#             'root': '/',
#             'forcePathsOnDatasetsImport': True,
#             'dkuProperties': [],
#             'namingRule': {}
#         },
#         'name': 'filesystem_root',
#         'type': 'Filesystem',
#         'allowWrite': False,
#         'allowManagedDatasets': False,
#         'allowManagedFolders': True,
#         'useGlobalProxy': True,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     },
#     'bigquery': {
#         'params': {
#             'credentialsMode': 'KEYPAIR',
#             'projectId': 'atsao',
#             'keyPath': '/Users/rendo/Downloads/atsao-290417-dcd35a141864.json',
#             'driverMode': 'DRIVERLESS',
#             'useAutoFastPath': False,
#             'namingRule': {
#                 'tableNameDatasetNamePrefix': '${projectKey}_',
#                 'canOverrideCatalogInManagedDatasetCreation': False,
#                 'canOverrideSchemaInManagedDatasetCreation': False
#             },
#             'useTruncate': False,
#             'autocommitMode': False,
#             'properties': [
#                 {
#                     'name': 'Timeout',
#                     'value': '180',
#                     'secret': False
#                 }
#             ],
#             'dkuProperties': [],
#             'useAsMetastoreSource': False,
#             'metastoreSourceType': 'SPARKSQL_THRIFT'
#         },
#         'name': 'bigquery',
#         'type': 'BigQuery',
#         'creationTag': {
#             'versionNumber': 0,
#             'lastModifiedBy': {'login': 'admin'},
#             'lastModifiedOn': 1651640996836
#         },
#         'allowWrite': True,
#         'allowManagedDatasets': True,
#         'allowManagedFolders': False,
#         'useGlobalProxy': False,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     },
#     'SupportS3': {
#         'params': {
#             'credentialsMode': 'KEYPAIR',
#             'accessKey': 'AKIA5G7CKA4JUNU3A7X5',
#             'secretKey':
#                 'e:AES:X2:8fhdZ4fjiqZRG3KdjEWO8tojOpMETY5jVdwzSrWKASU8NYlKo6/'
#                 'Qvwxq0FAjN0DxLacpyrsW8Ax+rrmsj7d5wEzEU/KDn30yC+'
#                 '6lYwWiDuUPmSGq9FM7TQ==',
#             'defaultManagedBucket': 'dku-support-availability',
#             'defaultManagedPath': '/dataiku',
#             'regionOrEndpoint': 'ap-northeast-1',
#             'hdfsInterface': 'S3A',
#             'encryptionMode': 'NONE',
#             'switchToRegionFromBucket': True,
#             'usePathMode': False,
#             'metastoreSynchronizationMode': 'NO_SYNC',
#             'customAWSCredentialsProviderParams': [],
#             'dkuProperties': [],
#             'namingRule': {}
#         },
#         'name': 'SupportS3',
#         'type': 'EC2',
#         'creationTag': {
#             'versionNumber': 0,
#             'lastModifiedBy': {'login': 'admin'},
#             'lastModifiedOn': 1650776513936
#         },
#         'allowWrite': True,
#         'allowManagedDatasets': True,
#         'allowManagedFolders': True,
#         'useGlobalProxy': False,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     },
#     'RedShift': {
#         'params': {
#             'redshiftAuthenticationMode': 'USER_PASSWORD',
#             'port': 5439,
#             'driverMode': 'MANAGED_LEGACY_POSTGRESQL',
#             'useAutoFastPath': False,
#             'host': 'redshift-cl-support.cslgnckqx0d9.eu-west-1.redshift.amazonaws.com',
#             'user': 'awsuser',
#             'password':
#                 'e:AES:X2:vvdS9F6Mr5ry+MtPbpgM0Dka2Jw3PMAMP4KIlKm7JEPNYYoVQ/'
#                 'nLhh2yjzx8wvY3pwgbAGom9YRJ',
#             'db': 'dev',
#             'useURL': False,
#             'namingRule': {
#                 'tableNameDatasetNamePrefix': 'rendo/',
#                 'canOverrideCatalogInManagedDatasetCreation': False,
#                 'schemaName': 'dataiku',
#                 'canOverrideSchemaInManagedDatasetCreation': False
#             },
#             'useTruncate': False,
#             'autocommitMode': False,
#             'properties': [],
#             'dkuProperties': [],
#             'useAsMetastoreSource': False,
#             'metastoreSourceType': 'SPARKSQL_THRIFT'
#         },
#         'name': 'RedShift',
#         'type': 'Redshift',
#         'creationTag': {
#             'versionNumber': 0,
#             'lastModifiedBy': {'login': 'admin'},
#             'lastModifiedOn': 1654645502643
#         },
#         'allowWrite': True,
#         'allowManagedDatasets': True,
#         'allowManagedFolders': False,
#         'useGlobalProxy': False,
#         'maxActivities': 0,
#         'customFields': {},
#         'credentialsMode': 'GLOBAL',
#         'customBasicConnectionCredentialProviderParams': [],
#         'usableBy': 'ALL',
#         'allowedGroups': [],
#         'detailsReadability': {'readableBy': 'NONE', 'allowedGroups': []},
#         'indexingSettings': {
#             'indexIndices': False,
#             'indexForeignKeys': False,
#             'indexSystemTables': False
#         }
#     }
# }
