# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
client = dataiku.api_client()
projects =  client.get_project("EVERYTHING")
dataset = projects.get_dataset("SakeElasticSearch")
                               
mydataset_md = dataset.get_settings()
dataset.clear()           
settings  = mydataset_md.get_raw()

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': 'sakeelasticsearch',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
settings['params']['index'] = dataiku.get_custom_variables()["year"]

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': '2020',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
mydataset_md.save()

# %%
dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
# Out:
# ---------------------------------------------------------------------------
# DataikuException                          Traceback (most recent call last)
# <ipython-input-30-568901402849> in <module>
# ----> 1 dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/dataset.py in build(self, job_type, partitions, wait, no_fail)
#     288         jd.with_output(self.dataset_name, partition=partitions)
#     289         if wait:
# --> 290             return jd.start_and_wait()
#     291         else:
#     292             return jd.start()
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/project.py in start_and_wait(self, no_fail)
#    1715         job = self.start()
#    1716         waiter = DSSJobWaiter(job)
# -> 1717         waiter.wait(no_fail)
#    1718         return job
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/job.py in wait(self, no_fail)
#      63                     break
#      64                 else:
# ---> 65                     raise DataikuException("Job run did not finish. Status: %s" % (job_state))
#      66         return job_state
#
# DataikuException: Job run did not finish. Status: FAILED

# %%
import dataiku


temp = dataiku.get_custom_variables()['year']
new = int(temp) + 1
dataiku.set_custom_variables({'year':str(new)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3fe0063f22f9> in <module>
#       4 temp = dataiku.get_custom_variables()['year']
#       5 new = int(temp) + 1
# ----> 6 dataiku.set_custom_variables({'year':str(new)})
#
# AttributeError: module 'dataiku' has no attribute 'set_custom_variables'

# %%
import dataikuapi
host = "http://localhost:11200"
apiKey = "GrFWHV8ghdnHUmh3SI4M0jguBqfFC55x"
client = dataikuapi.DSSClient(host, apiKey)

# %%
projects = client.list_projects()

# %%
for project in projects:
    pp.pprint(project['name'])
    pp.pprint(client.get_project("EVERYTHING").list_jobs())
# Out:
# 'Audit Log Analysis'
# [   {   'def': {   'id': 'Build_a__NP__2021-09-09T18-28-12.664',
#                    'initiationTimestamp': 1631212092664,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build a (NP)',
#                    'outputs': [   {   'targetDataset': 'spa0dts8',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_spa0dts8',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631212095514,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631212092873,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_a__NP__2021-09-09T18-27-42.053',
#                    'initiationTimestamp': 1631212062053,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build a (NP)',
#                    'outputs': [   {   'targetDataset': 'spa0dts8',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_spa0dts8',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631212066860,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631212062268,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_25287_prepared__NP__2021-09-09T18-27-32.181',
#                    'initiationTimestamp': 1631212052181,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build 25287_prepared (NP)',
#                    'outputs': [   {   'targetDataset': '25287_prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_25287_prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631212054437,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631212052426,
#         'state': 'DONE',
#         'warningsCount': 1},
#     {   'def': {   'id': 'Build_a__NP__2021-09-09T18-27-02.524',
#                    'initiationTimestamp': 1631212022524,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build a (NP)',
#                    'outputs': [   {   'targetDataset': 'spa0dts8',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_spa0dts8',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631212027709,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631212022905,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_a__NP__2021-09-09T18-26-37.173',
#                    'initiationTimestamp': 1631211997173,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build a (NP)',
#                    'outputs': [   {   'targetDataset': 'spa0dts8',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_spa0dts8',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631212000017,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631211997410,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_25287_prepared__NP__2021-09-09T18-24-15.941',
#                    'initiationTimestamp': 1631211855941,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build 25287_prepared (NP)',
#                    'outputs': [   {   'targetDataset': '25287_prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_25287_prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631211858457,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631211856251,
#         'state': 'DONE',
#         'warningsCount': 15},
#     {   'def': {   'id': 'Build_BG_A__NP__2021-09-09T17-20-20.981',
#                    'initiationTimestamp': 1631208020981,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build BG_A (NP)',
#                    'outputs': [   {   'targetDataset': 'BG_A',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_BG_A',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631208029319,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631208021901,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_bca__NP__2021-09-07T18-35-48.450',
#                    'initiationTimestamp': 1631039748450,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build bca (NP)',
#                    'outputs': [   {   'targetDataset': 'bca',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_bca',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631039773782,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631039762186,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_year__NP__2021-09-07T13-31-28.883',
#                    'initiationTimestamp': 1631021488883,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build year (NP)',
#                    'outputs': [   {   'targetDataset': 'year',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631021490120,
#         'kernelPid': 0,
#         'scenarioId': 'variable',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-09-07-09-31-26-822',
#         'stableState': True,
#         'startTime': 1631021489125,
#         'state': 'DONE',
#         'stepId': 'custom_python_BPUOLw038ObAUOpRBqDA7Q',
#         'stepRunId': '2021-09-07-09-31-26-980',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_year__NP__2021-09-07T13-29-44.470',
#                    'initiationTimestamp': 1631021384470,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build year (NP)',
#                    'outputs': [   {   'targetDataset': 'year',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631021386046,
#         'kernelPid': 0,
#         'scenarioId': 'variable',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-09-07-09-29-41-499',
#         'stableState': True,
#         'startTime': 1631021384796,
#         'state': 'DONE',
#         'stepId': 'custom_python_BPUOLw038ObAUOpRBqDA7Q',
#         'stepRunId': '2021-09-07-09-29-41-697',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_year__NP__2021-09-07T13-24-40.193',
#                    'initiationTimestamp': 1631021080193,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build year (NP)',
#                    'outputs': [   {   'targetDataset': 'year',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631021081523,
#         'kernelPid': 0,
#         'scenarioId': 'variable',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-09-07-09-24-38-284',
#         'stableState': True,
#         'startTime': 1631021080408,
#         'state': 'DONE',
#         'stepId': 'custom_python_BPUOLw038ObAUOpRBqDA7Q',
#         'stepRunId': '2021-09-07-09-24-38-507',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_year__NP__2021-09-07T13-24-19.688',
#                    'initiationTimestamp': 1631021059688,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build year (NP)',
#                    'outputs': [   {   'targetDataset': 'year',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631021060930,
#         'kernelPid': 0,
#         'scenarioId': 'variable',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-09-07-09-24-17-437',
#         'stableState': True,
#         'startTime': 1631021059949,
#         'state': 'DONE',
#         'stepId': 'custom_python_BPUOLw038ObAUOpRBqDA7Q',
#         'stepRunId': '2021-09-07-09-24-17-690',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_year__NP__2021-09-07T13-24-09.375',
#                    'initiationTimestamp': 1631021049375,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build year (NP)',
#                    'outputs': [   {   'targetDataset': 'year',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631021050657,
#         'kernelPid': 0,
#         'scenarioId': 'variable',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-09-07-09-24-01-351',
#         'stableState': True,
#         'startTime': 1631021049608,
#         'state': 'DONE',
#         'stepId': 'custom_python_BPUOLw038ObAUOpRBqDA7Q',
#         'stepRunId': '2021-09-07-09-24-01-590',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_year__NP__2021-09-07T13-15-11.041',
#                    'initiationTimestamp': 1631020511041,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build year (NP)',
#                    'outputs': [   {   'targetDataset': 'year',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631020512179,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631020511273,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_CoronsES__NP__2021-09-07T13-14-01.285',
#                    'initiationTimestamp': 1631020441285,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build CoronsES (NP)',
#                    'outputs': [   {   'targetDataset': 'CoronsES',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631020442432,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631020441479,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_CoronsES__NP__2021-09-07T13-12-46.610',
#                    'initiationTimestamp': 1631020366610,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build CoronsES (NP)',
#                    'outputs': [   {   'targetDataset': 'CoronsES',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631020384919,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631020366795,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_CoronsES__NP__2021-09-07T13-11-54.550',
#                    'initiationTimestamp': 1631020314550,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build CoronsES (NP)',
#                    'outputs': [   {   'targetDataset': 'CoronsES',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631020332309,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631020314743,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_SakeElasticSearch__NP__2021-09-07T13-10-44.304',
#                    'initiationTimestamp': 1631020244304,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeElasticSearch (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeElasticSearch',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631020249599,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631020244516,
#         'state': 'FAILED',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_SakeElasticSearch__NP__2021-09-07T13-06-33.269',
#                    'initiationTimestamp': 1631019993269,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeElasticSearch (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeElasticSearch',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1631020000954,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1631019993842,
#         'state': 'FAILED',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_Corona1_partitioned_copy__2021__2021-09-06T14-37-47.489',
#                    'initiationTimestamp': 1630939067489,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Corona1_partitioned_copy (2021)',
#                    'outputs': [   {   'targetDataset': 'Corona1_partitioned_copy',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': '2021',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Corona1_partitioned_copy',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630939091627,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630939067716,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Corona1_partitioned_copy__2021__2021-09-06T14-37-02.252',
#                    'initiationTimestamp': 1630939022252,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Corona1_partitioned_copy (2021)',
#                    'outputs': [   {   'targetDataset': 'Corona1_partitioned_copy',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': '2021',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Corona1_partitioned_copy',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630939025689,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630939022751,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-24-03.296',
#                    'initiationTimestamp': 1630931043296,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630931571561,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630931043842,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-18-05.778',
#                    'initiationTimestamp': 1630930685778,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 0,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630930686380,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-14-25.553',
#                    'initiationTimestamp': 1630930465553,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630930470649,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630930469771,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-13-43.389',
#                    'initiationTimestamp': 1630930423389,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630930429017,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630930428085,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-13-26.136',
#                    'initiationTimestamp': 1630930406136,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 0,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630930421717,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_FedEx__NP__2021-09-03T19-28-23.436',
#                    'initiationTimestamp': 1630697303436,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build FedEx (NP)',
#                    'outputs': [   {   'targetDataset': 'FedEx',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_FedEx',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630697318339,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630697308586,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_pusparksleep__NP__2021-09-02T18-14-48.022',
#                    'initiationTimestamp': 1630606488022,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build pusparksleep (NP)',
#                    'outputs': [   {   'targetDataset': 'pusparksleep',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_pusparksleep',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630606490239,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630606488253,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T17-48-28.003',
#                    'initiationTimestamp': 1630604908003,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630604927030,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630604912661,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T17-47-03.298',
#                    'initiationTimestamp': 1630604823298,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630604887547,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630604823598,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T16-12-35.701',
#                    'initiationTimestamp': 1630599155701,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630602170928,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630599155917,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T16-04-48.187',
#                    'initiationTimestamp': 1630598688187,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630598700556,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630598688427,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T16-04-07.610',
#                    'initiationTimestamp': 1630598647610,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630598655899,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630598647797,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T16-03-03.676',
#                    'initiationTimestamp': 1630598583676,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630598606726,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630598583929,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-02T15-58-57.618',
#                    'initiationTimestamp': 1630598337618,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Fastparquetdataset (NP)',
#                    'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Fastparquetdataset',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630598546410,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630598337870,
#         'state': 'ABORTED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Corona1_prepared__NP__2021-09-02T15-12-07.576',
#                    'initiationTimestamp': 1630595527576,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Corona1_prepared (NP)',
#                    'outputs': [   {   'targetDataset': 'Corona1_prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Corona1_prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630595536199,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630595527910,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_testforlog__NP__2021-09-02T13-48-01.431',
#                    'initiationTimestamp': 1630590481431,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build testforlog (NP)',
#                    'outputs': [   {   'targetDataset': 'testforlog',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_testforlog',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630590491025,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630590481987,
#         'state': 'FAILED',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet_3_newsheet1_stacked__NP__2021-08-31T15-38-28.540',
#                    'initiationTimestamp': 1630424308540,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet_3_newsheet1_stacked '
#                            '(NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet_3_newsheet1_stacked',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Untitled_spreadsheet_3_newsheet1_stacked',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630424311787,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630424308763,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet_3_newsheet1_stacked__NP__2021-08-31T15-26-12.845',
#                    'initiationTimestamp': 1630423572845,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet_3_newsheet1_stacked '
#                            '(NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet_3_newsheet1_stacked',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Untitled_spreadsheet_3_newsheet1_stacked',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630423575550,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630423573047,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet_3_newsheet1_stacked__NP__2021-08-31T15-25-27.685',
#                    'initiationTimestamp': 1630423527685,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet_3_newsheet1_stacked '
#                            '(NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet_3_newsheet1_stacked',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': True,
#                    'type': 'RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630423530602,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630423527886,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet_3_newsheet1_stacked__NP__2021-08-31T15-24-29.205',
#                    'initiationTimestamp': 1630423469205,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet_3_newsheet1_stacked '
#                            '(NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet_3_newsheet1_stacked',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Untitled_spreadsheet_3_newsheet1_stacked',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630423471950,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630423469452,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet_1_Sheet1_stacked__NP__2021-08-31T15-23-58.360',
#                    'initiationTimestamp': 1630423438360,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet_1_Sheet1_stacked (NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet_1_Sheet1_stacked',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Untitled_spreadsheet_1_Sheet1_stacked',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630423440302,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630423438702,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet__1__prepared__NP__2021-08-31T15-17-35.644',
#                    'initiationTimestamp': 1630423055644,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet__1__prepared (NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet__1__prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Untitled_spreadsheet__1__prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630423062809,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630423060270,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Untitled_spreadsheet__1__prepared__NP__2021-08-31T15-17-02.599',
#                    'initiationTimestamp': 1630423022599,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Untitled_spreadsheet__1__prepared (NP)',
#                    'outputs': [   {   'targetDataset': 'Untitled_spreadsheet__1__prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_Untitled_spreadsheet__1__prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630423029669,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630423027225,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_2_prepared__NP__2021-08-31T15-14-59.992',
#                    'initiationTimestamp': 1630422899992,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build 2_prepared (NP)',
#                    'outputs': [   {   'targetDataset': '2_prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_2_prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630422906735,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630422904330,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_filesystem__NP__2021-08-26T19-20-07.839',
#                    'initiationTimestamp': 1630005607839,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build filesystem (NP)',
#                    'outputs': [   {   'targetDataset': 'qWeVti46',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_qWeVti46',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1630005921541,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1630005608027,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_truncate_prepared__NP__2021-08-25T14-36-24.399',
#                    'initiationTimestamp': 1629902184399,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build truncate_prepared (NP)',
#                    'outputs': [   {   'targetDataset': 'truncate_prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_truncate_prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1629902198211,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1629902190344,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_25287_prepared__NP__2021-08-19T23-27-18.147',
#                    'initiationTimestamp': 1629415638147,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build 25287_prepared (NP)',
#                    'outputs': [   {   'targetDataset': '25287_prepared',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_25287_prepared',
#                    'refreshHiveMetastore': True,
# ...
#                    'recipe': 'compute_sakePostGreSQL_prepared',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627533979468,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627533976764,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_ToS3Bucket__NP__2021-07-29T00-10-51.455',
#                    'initiationTimestamp': 1627517451455,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build ToS3Bucket (NP)',
#                    'outputs': [   {   'targetDataset': 'tqcjRuqM',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_tqcjRuqM',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627517455693,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627517451532,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_ToS3Bucket__NP__2021-07-29T00-09-56.402',
#                    'initiationTimestamp': 1627517396402,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build ToS3Bucket (NP)',
#                    'outputs': [   {   'targetDataset': 'tqcjRuqM',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'MANAGED_FOLDER'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_tqcjRuqM',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627517407460,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627517396794,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_SakeMongo__NP__2021-07-28T02-32-51.889',
#                    'initiationTimestamp': 1627439571889,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeMongo (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeMongo',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SakeMongo',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627439579590,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627439572025,
#         'state': 'DONE',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_SakeOracle__NP__2021-07-28T02-30-07.854',
#                    'initiationTimestamp': 1627439407854,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeOracle (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeOracle',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SakeOracle',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627439420024,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627439407973,
#         'state': 'FAILED',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_sakePostGreSQL__NP__2021-07-28T02-29-00.884',
#                    'initiationTimestamp': 1627439340884,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build sakePostGreSQL (NP)',
#                    'outputs': [   {   'targetDataset': 'sakePostGreSQL',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_sakePostGreSQL',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627439343994,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627439341019,
#         'state': 'DONE',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_SakeMySQL__NP__2021-07-28T02-17-59.768',
#                    'initiationTimestamp': 1627438679768,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeMySQL (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeMySQL',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SakeMySQL',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627438681380,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627438679861,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_SakeMySQL__NP__2021-07-28T02-14-55.120',
#                    'initiationTimestamp': 1627438495120,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeMySQL (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeMySQL',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SakeMySQL',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627438496778,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627438495238,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_SakeMySQL__NP__2021-07-28T02-06-24.123',
#                    'initiationTimestamp': 1627437984123,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeMySQL (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeMySQL',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SakeMySQL',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627437985670,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627437984238,
#         'state': 'FAILED',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_SakeS3_avro__NP__2021-07-28T02-05-38.012',
#                    'initiationTimestamp': 1627437938012,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SakeS3_avro (NP)',
#                    'outputs': [   {   'targetDataset': 'SakeS3_avro',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SakeS3_avro',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627437982079,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627437951862,
#         'state': 'DONE',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_SaketoS3__csv__NP__2021-07-28T02-04-59.952',
#                    'initiationTimestamp': 1627437899952,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build SaketoS3__csv (NP)',
#                    'outputs': [   {   'targetDataset': 'SaketoS3__csv',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'compute_SaketoS3__csv',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627437926131,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627437900120,
#         'state': 'DONE',
#         'warningsCount': 122},
#     {   'def': {   'id': 'Build_Corona1_partitioned__2021__2021-07-27T23-34-47.539',
#                    'initiationTimestamp': 1627428887539,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Corona1_partitioned (2021)',
#                    'outputs': [   {   'targetDataset': 'Corona1_partitioned',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': '2021',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': True,
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1627428897843,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1627428888016,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_FITNESS_checks__NP__2021-07-19T07-51-38.997',
#                    'initiationTimestamp': 1626681098997,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build FITNESS_checks (NP)',
#                    'outputs': [   {   'targetDataset': 'FITNESS_checks',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': True,
#                    'type': 'RECURSIVE_BUILD'},
#         'endTime': 1626681115334,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1626681114996,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'sched_build_2021-07-14T23-11-53.802',
#                    'initiationTimestamp': 1626304313802,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'sched_build',
#                    'outputs': [   {   'targetDataset': 'Corona_MySQL',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'SCHEDULER',
#                    'type': 'RECURSIVE_BUILD'},
#         'endTime': 1626304324986,
#         'kernelPid': 0,
#         'scenarioId': 'Community_sync_automation',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-07-15-08-11-53-691',
#         'stableState': True,
#         'startTime': 1626304314300,
#         'state': 'DONE',
#         'stepId': 'build_0_true_d_Corona_MySQL',
#         'stepRunId': '2021-07-15-08-11-53-790',
#         'warningsCount': 0},
#     {   'def': {   'id': 'sched_build_2021-07-14T01-01-27.136',
#                    'initiationTimestamp': 1626224487136,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'sched_build',
#                    'outputs': [   {   'targetDataset': 'Corona_MySQL',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'SCHEDULER',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1626224512258,
#         'kernelPid': 0,
#         'scenarioId': 'Community_sync_automation',
#         'scenarioProjectKey': 'EVERYTHING',
#         'scenarioRunId': '2021-07-14-10-01-27-016',
#         'stableState': True,
#         'startTime': 1626224501667,
#         'state': 'DONE',
#         'stepId': 'build_1_true_d_Corona_MySQL',
#         'stepRunId': '2021-07-14-10-01-27-120',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_Corona2__NP__2021-07-09T05-33-19.276',
#                    'initiationTimestamp': 1625808799276,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build Corona2 (NP)',
#                    'outputs': [   {   'targetDataset': 'Corona2',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': 'NP',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'refreshHiveMetastore': False,
#                    'triggeredFrom': 'API',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1625808815468,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1625808812663,
#         'state': 'DONE',
#         'warningsCount': 0},
#     {   'def': {   'id': 'Build_NewPartitions__2021__2021-07-09T02-16-59.096',
#                    'initiationTimestamp': 1625797019096,
#                    'initiator': 'admin',
#                    'mailNotification': False,
#                    'name': 'Build NewPartitions (2021)',
#                    'outputs': [   {   'targetDataset': 'NewPartitions',
#                                       'targetDatasetProjectKey': 'EVERYTHING',
#                                       'targetPartition': '2021',
#                                       'type': 'DATASET'}],
#                    'projectKey': 'EVERYTHING',
#                    'recipe': 'recipe_from_notebook_community_write_partitions',
#                    'refreshHiveMetastore': True,
#                    'triggeredFrom': 'RECIPE',
#                    'type': 'NON_RECURSIVE_FORCED_BUILD'},
#         'endTime': 1625797052748,
#         'kernelPid': 0,
#         'stableState': True,
#         'startTime': 1625797033243,
#         'state': 'DONE',
#         'warningsCount': 0}]
