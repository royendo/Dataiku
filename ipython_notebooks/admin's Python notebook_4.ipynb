# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
import dataikuapi
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
client = dataiku.api_client()
projects =  client.get_project("EVERYTHING")
dataset = projects.get_dataset("audit")
        
print(dataset.get_settings())
metrics = dataset.get_last_metric_values()
#https://github.com/dataiku/dss-code-samples/blob/779d4473f7e8ec9e65ad99ce2c4aaf782bc59e73/_old/dataset_last_run_job_info/get_job_info_for_datasets_in_project.py
for metric in metrics.raw['metrics']:
    #pp.pprint(metric)
    try:
        if (metric['computingProbe'] == 'records' and metric['displayedAsMetric'] == True):
            recordCount = metric['lastValues'][0]['value']
    except:
        error = "uh"
print("The record count is " + recordCount)
#mydataset_md = dataset.get_settings()
#dataset.clear()           
#settings  = mydataset_md.get_raw()
# Out:
# <dataikuapi.dss.dataset.FSLikeDatasetSettings object at 0x7fa7fbc95e10>
# The record count is 196786

# %%
# Out:
# x
# '196708'

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'filesystem_root',
#     'filesSelectionRules': {   'excludeRules': [],
#                                'explicitFiles': [],
#                                'includeRules': [],
#                                'mode': 'ALL'},
#     'notReadyIfEmpty': False,
#     'path': '/Users/rendo/Library/DataScienceStudio/dss_home/run/audit/audit.log'}

# %%
settings['params']['index'] = dataiku.get_custom_variables()["year"]

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': '2020',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
mydataset_md.save()

# %%
dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
# Out:
# ---------------------------------------------------------------------------
# DataikuException                          Traceback (most recent call last)
# <ipython-input-30-568901402849> in <module>
# ----> 1 dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/dataset.py in build(self, job_type, partitions, wait, no_fail)
#     288         jd.with_output(self.dataset_name, partition=partitions)
#     289         if wait:
# --> 290             return jd.start_and_wait()
#     291         else:
#     292             return jd.start()
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/project.py in start_and_wait(self, no_fail)
#    1715         job = self.start()
#    1716         waiter = DSSJobWaiter(job)
# -> 1717         waiter.wait(no_fail)
#    1718         return job
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/job.py in wait(self, no_fail)
#      63                     break
#      64                 else:
# ---> 65                     raise DataikuException("Job run did not finish. Status: %s" % (job_state))
#      66         return job_state
#
# DataikuException: Job run did not finish. Status: FAILED

# %%
import dataiku


temp = dataiku.get_custom_variables()['year']
new = int(temp) + 1
dataiku.set_custom_variables({'year':str(new)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3fe0063f22f9> in <module>
#       4 temp = dataiku.get_custom_variables()['year']
#       5 new = int(temp) + 1
# ----> 6 dataiku.set_custom_variables({'year':str(new)})
#
# AttributeError: module 'dataiku' has no attribute 'set_custom_variables'

# %%
import dataikuapi
host = "http://localhost:11200"
apiKey = "GrFWHV8ghdnHUmh3SI4M0jguBqfFC55x"
client = dataikuapi.DSSClient(host, apiKey)
#client = dataiku.api_client()

# %%
projects = client.list_project_keys()

# %%
import dataikuapi
host = "http://localhost:11200"
apiKey = "GrFWHV8ghdnHUmh3SI4M0jguBqfFC55x"
client = dataikuapi.DSSClient(host, apiKey)
#client = dataiku.api_client()
projects = client.list_project_keys()
for project in projects:
    pp.pprint(project)
    jobs = client.get_project(project).list_jobs()
    
    for job in jobs:
        #if (job['endTime']==0 and job['stableState'] == False):
        if (job['endTime']==0):
            print(job['def']['name'])
            pp.pprint(job)
# Out:
# 'AUDITLOGANALYSIS'
# 'AUDITTEST'
# 'DKU_EXAM_ADV_DESIGNER'
# 'DKU_EXAM_ML_PRACTITIONER'
# 'DKU_TSHIRTS'
# 'DKU_TUTORIAL_PARTITIONED_MODELS'
# 'DKU_TUTORIAL_REDISPATCHPARTITIONS'
# 'DKU_TUT_APIS'
# 'DKU_TUT_CODE_NOTEBOOKS'
# 'DKU_TUT_CUSTOMPREPROCESSING'
# 'DKU_TUT_PLUGINDEV'
# 'DKU_TUT_SHARECODE_A'
# 'DKU_TUT_SHARECODE_B'
# 'DKU_TUT_VARCOD'
# 'DKU_TUT_VARCOD_NzVCF42V'
# 'DS_AI_INNOV_RINVOQ_ADOPTION_PULSE'
# 'EVERYTHING'
# Build aaa (NP)
# {   'def': {   'id': 'Build_aaa__NP__2021-09-09T20-54-35.315',
#                'initiationTimestamp': 1631220875315,
#                'initiator': 'admin',
#                'mailNotification': False,
#                'name': 'Build aaa (NP)',
#                'outputs': [   {   'targetDataset': 'aaa',
#                                   'targetDatasetProjectKey': 'EVERYTHING',
#                                   'targetPartition': 'NP',
#                                   'type': 'DATASET'}],
#                'projectKey': 'EVERYTHING',
#                'recipe': 'compute_aaa',
#                'refreshHiveMetastore': True,
#                'triggeredFrom': 'RECIPE',
#                'type': 'NON_RECURSIVE_FORCED_BUILD'},
#     'endTime': 0,
#     'kernelPid': 0,
#     'stableState': False,
#     'startTime': 1631220875524,
#     'warningsCount': 0}
# Build Fastparquetdataset (NP)
# {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-18-05.778',
#                'initiationTimestamp': 1630930685778,
#                'initiator': 'admin',
#                'mailNotification': False,
#                'name': 'Build Fastparquetdataset (NP)',
#                'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                   'targetDatasetProjectKey': 'EVERYTHING',
#                                   'targetPartition': 'NP',
#                                   'type': 'DATASET'}],
#                'projectKey': 'EVERYTHING',
#                'recipe': 'compute_Fastparquetdataset',
#                'refreshHiveMetastore': True,
#                'triggeredFrom': 'RECIPE',
#                'type': 'NON_RECURSIVE_FORCED_BUILD'},
#     'endTime': 0,
#     'kernelPid': 0,
#     'stableState': True,
#     'startTime': 1630930686380,
#     'state': 'ABORTED',
#     'warningsCount': 0}
# Build Fastparquetdataset (NP)
# {   'def': {   'id': 'Build_Fastparquetdataset__NP__2021-09-06T12-13-26.136',
#                'initiationTimestamp': 1630930406136,
#                'initiator': 'admin',
#                'mailNotification': False,
#                'name': 'Build Fastparquetdataset (NP)',
#                'outputs': [   {   'targetDataset': 'Fastparquetdataset',
#                                   'targetDatasetProjectKey': 'EVERYTHING',
#                                   'targetPartition': 'NP',
#                                   'type': 'DATASET'}],
#                'projectKey': 'EVERYTHING',
#                'recipe': 'compute_Fastparquetdataset',
#                'refreshHiveMetastore': True,
#                'triggeredFrom': 'RECIPE',
#                'type': 'NON_RECURSIVE_FORCED_BUILD'},
#     'endTime': 0,
#     'kernelPid': 0,
#     'stableState': True,
#     'startTime': 1630930421717,
#     'state': 'ABORTED',
#     'warningsCount': 0}
# 'MANAGEDFOLDERS'
# 'SCENARIOPYTHONSTEP'
# 'TEXTEXTRACTIONDEMO'

# %%
import dataiku
import time

client = dataiku.api_client()
projects = client.list_project_keys()
running = True


while running == True:
    running = False
    #time.sleep(60)
    for project in projects:
        projectjob = client.get_project(project)
        jobs = projectjob.list_jobs()
        for job in jobs:
            if (job['endTime']==0):
                running = True
                print("Jobs still running:" + job['def']['name'])
print("No Jobs running")
# Out:
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d7702ea1488f> in <module>
#      12     for project in projects:
#      13         projectjob = client.get_project(project)
# ---> 14         jobs = projectjob.list_jobs()
#      15         for job in jobs:
#      16             if (job['endTime']==0):
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/project.py in list_jobs(self)
#     809         """
#     810         return self.client._perform_json(
# --> 811             "GET", "/projects/%s/jobs/" % self.project_key)
#     812
#     813     def get_job(self, id):
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dssclient.py in _perform_json(self, method, path, params, body, files, raw_body)
#    1035
#    1036     def _perform_json(self, method, path, params=None, body=None,files=None, raw_body=None):
# -> 1037         return self._perform_http(method, path,  params=params, body=body, files=files, stream=False, raw_body=raw_body).json()
#    1038
#    1039     def _perform_raw(self, method, path, params=None, body=None,files=None, raw_body=None):
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dssclient.py in _perform_http(self, method, path, params, body, stream, files, raw_body)
#    1018                     params=params, data=body,
#    1019                     files = files,
# -> 1020                     stream = stream)
#    1021             http_res.raise_for_status()
#    1022             return http_res
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import dataiku
client = dataiku.api_client()

project=client.get_project("EVERYTHING")
project.duplicate("EVERYTHING2","EVERYTHING2")
# Out:
# {'projectKey': 'EVERYTHING',
#  'targetProjectKey': 'EVERYTHING2',
#  'messages': [{'severity': 'WARNING',
#    'isFatal': False,
#    'code': 'WARN_BUNDLE_ACTIVATE_DATASET_NO_DATA',
#    'title': 'No data for bundled dataset',
#    'details': 'No data for EVERYTHING2.abcd1234',
#    'message': 'No data for bundled dataset: No data for EVERYTHING2.abcd1234'},
#   {'severity': 'WARNING',
#    'isFatal': False,
#    'code': 'WARN_BUNDLE_ACTIVATE_DATASET_NO_DATA',
#    'title': 'No data for bundled dataset',
#    'details': 'No data for EVERYTHING2.shogun',
#    'message': 'No data for bundled dataset: No data for EVERYTHING2.shogun'},
#   {'severity': 'ERROR',
#    'isFatal': False,
#    'code': 'WARN_BUNDLE_ACTIVATE_DATASET_LOAD_FAILED',
#    'title': 'Failed loading data for a dataset',
#    'details': 'audit: Unable to create directory /EVERYTHING2.audit',
#    'message': 'Failed loading data for a dataset: audit: Unable to create directory /EVERYTHING2.audit'},
#   {'severity': 'WARNING',
#    'isFatal': False,
#    'code': 'WARN_FOLDER_CONNECTION_TYPE_ERROR',
#    'title': 'Invalid connection or folder type',
#    'details': 'Failed to ensure that the folder type matches its connection : Connection name not specified',
#    'message': 'Invalid connection or folder type: Failed to ensure that the folder type matches its connection : Connection name not specified'}],
#  'maxSeverity': 'ERROR',
#  'anyMessage': True,
#  'success': False,
#  'warning': True,
#  'error': True,
#  'fatal': False}

# %%
app = client.get_app("PROJECT_EVERYTHING")

# %%
print(app.get_instances())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-89ef84623c59> in <module>
# ----> 1 print(app.get_instances())
#
# AttributeError: 'DSSApp' object has no attribute 'get_instances'

# %%
client = dataiku.api_client()
with open("/Users/rendo/Downloads/Archive_SQLE 2 2.zip", "rb") as f:
    client.install_plugin_from_archive(f)

# %%
client = dataiku.api_client()
projects =  client.get_project("EVERYTHING")
dataset = projects.get_dataset("EVERYTHING_aaaaa")
        
metrics = dataset.get_last_metric_values()
#https://github.com/dataiku/dss-code-samples/blob/779d4473f7e8ec9e65ad99ce2c4aaf782bc59e73/_old/dataset_last_run_job_info/get_job_info_for_datasets_in_project.py
for metric in metrics.raw['metrics']:
    pp.pprint(metric)
    try:
         recordCount = metric
    except:
        error = "uh"
print(recordCount)
#mydataset_md = dataset.get_settings()
#dataset.clear()           
#settings  = mydataset_md.get_raw()
# Out:
# {   'computingProbe': 'basic',
#     'displayedAsMetric': True,
#     'lastValues': [   {   'computed': 1633720638070,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '60'}],
#     'meta': {'fullName': 'Column count', 'name': 'Column count'},
#     'metric': {   'dataType': 'BIGINT',
#                   'id': 'basic:COUNT_COLUMNS',
#                   'metricType': 'COUNT_COLUMNS',
#                   'type': 'basic'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of aged_65_older',
#                 'name': 'Count'},
#     'metric': {   'column': 'aged_65_older',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:aged_65_older',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of aged_70_older',
#                 'name': 'Count'},
#     'metric': {   'column': 'aged_70_older',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:aged_70_older',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of cardiovasc_death_rate',
#                 'name': 'Count'},
#     'metric': {   'column': 'cardiovasc_death_rate',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:cardiovasc_death_rate',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '90186'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of continent',
#                 'name': 'Count'},
#     'metric': {   'column': 'continent',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:continent',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '94657'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of date',
#                 'name': 'Count'},
#     'metric': {   'column': 'date',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:date',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of diabetes_prevalence',
#                 'name': 'Count'},
#     'metric': {   'column': 'diabetes_prevalence',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:diabetes_prevalence',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of excess_mortality',
#                 'name': 'Count'},
#     'metric': {   'column': 'excess_mortality',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:excess_mortality',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of extreme_poverty',
#                 'name': 'Count'},
#     'metric': {   'column': 'extreme_poverty',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:extreme_poverty',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of female_smokers',
#                 'name': 'Count'},
#     'metric': {   'column': 'female_smokers',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:female_smokers',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of gdp_per_capita',
#                 'name': 'Count'},
#     'metric': {   'column': 'gdp_per_capita',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:gdp_per_capita',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of handwashing_facilities',
#                 'name': 'Count'},
#     'metric': {   'column': 'handwashing_facilities',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:handwashing_facilities',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '46003'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of hosp_patients',
#                 'name': 'Count'},
#     'metric': {   'column': 'hosp_patients',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:hosp_patients',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '51035'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of hosp_patients_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'hosp_patients_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:hosp_patients_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of hospital_beds_per_thousand',
#                 'name': 'Count'},
#     'metric': {   'column': 'hospital_beds_per_thousand',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:hospital_beds_per_thousand',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of human_development_index',
#                 'name': 'Count'},
#     'metric': {   'column': 'human_development_index',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:human_development_index',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '49436'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of icu_patients',
#                 'name': 'Count'},
#     'metric': {   'column': 'icu_patients',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:icu_patients',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '46602'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of icu_patients_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'icu_patients_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:icu_patients_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '94657'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of iso_code',
#                 'name': 'Count'},
#     'metric': {   'column': 'iso_code',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:iso_code',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of life_expectancy',
#                 'name': 'Count'},
#     'metric': {   'column': 'life_expectancy',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:life_expectancy',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '94657'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of location',
#                 'name': 'Count'},
#     'metric': {   'column': 'location',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:location',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of male_smokers',
#                 'name': 'Count'},
#     'metric': {   'column': 'male_smokers',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:male_smokers',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of median_age',
#                 'name': 'Count'},
#     'metric': {   'column': 'median_age',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:median_age',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '91556'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_cases',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_cases',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_cases',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '9519'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_cases_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_cases_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_cases_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '90546'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_cases_smoothed',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_cases_smoothed',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_cases_smoothed',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '11815'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_cases_smoothed_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_cases_smoothed_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_cases_smoothed_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '81744'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_deaths',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_deaths',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_deaths',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '1496'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_deaths_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_deaths_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_deaths_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '90546'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_deaths_smoothed',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_deaths_smoothed',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_deaths_smoothed',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '42642'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_deaths_smoothed_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_deaths_smoothed_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_deaths_smoothed_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '24113'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_tests',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_tests',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_tests',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '88008'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_tests_per_thousand',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_tests_per_thousand',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_tests_per_thousand',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '84822'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_tests_smoothed',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_tests_smoothed',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_tests_smoothed',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '83866'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_tests_smoothed_per_thousand',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_tests_smoothed_per_thousand',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_tests_smoothed_per_thousand',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '65721'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_vaccinations',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_vaccinations',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_vaccinations',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '42808'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_vaccinations_smoothed',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_vaccinations_smoothed',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_vaccinations_smoothed',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of new_vaccinations_smoothed_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'new_vaccinations_smoothed_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:new_vaccinations_smoothed_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '66698'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of people_fully_vaccinated',
#                 'name': 'Count'},
#     'metric': {   'column': 'people_fully_vaccinated',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:people_fully_vaccinated',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '3344'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of people_fully_vaccinated_per_hundred',
#                 'name': 'Count'},
#     'metric': {   'column': 'people_fully_vaccinated_per_hundred',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:people_fully_vaccinated_per_hundred',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '87274'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of people_vaccinated',
#                 'name': 'Count'},
#     'metric': {   'column': 'people_vaccinated',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:people_vaccinated',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '85378'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of people_vaccinated_per_hundred',
#                 'name': 'Count'},
#     'metric': {   'column': 'people_vaccinated_per_hundred',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:people_vaccinated_per_hundred',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of population',
#                 'name': 'Count'},
#     'metric': {   'column': 'population',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:population',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of population_density',
#                 'name': 'Count'},
#     'metric': {   'column': 'population_density',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:population_density',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '84352'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of positive_rate',
#                 'name': 'Count'},
#     'metric': {   'column': 'positive_rate',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:positive_rate',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '42335'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of reproduction_rate',
#                 'name': 'Count'},
#     'metric': {   'column': 'reproduction_rate',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:reproduction_rate',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of stringency_index',
#                 'name': 'Count'},
#     'metric': {   'column': 'stringency_index',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:stringency_index',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '85108'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of tests_per_case',
#                 'name': 'Count'},
#     'metric': {   'column': 'tests_per_case',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:tests_per_case',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '57525'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of tests_units',
#                 'name': 'Count'},
#     'metric': {   'column': 'tests_units',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:tests_units',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '91559'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_cases',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_cases',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_cases',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '76311'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_cases_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_cases_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_cases_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '81588'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_deaths',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_deaths',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_deaths',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '861'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_deaths_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_deaths_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_deaths_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '79888'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_tests',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_tests',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_tests',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '94034'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_tests_per_thousand',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_tests_per_thousand',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_tests_per_thousand',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '85214'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_vaccinations',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_vaccinations',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_vaccinations',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '89887'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of total_vaccinations_per_hundred',
#                 'name': 'Count'},
#     'metric': {   'column': 'total_vaccinations_per_hundred',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:total_vaccinations_per_hundred',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '10432'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of weekly_hosp_admissions',
#                 'name': 'Count'},
#     'metric': {   'column': 'weekly_hosp_admissions',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:weekly_hosp_admissions',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '11706'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of weekly_hosp_admissions_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'weekly_hosp_admissions_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:weekly_hosp_admissions_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '13992'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of weekly_icu_admissions',
#                 'name': 'Count'},
#     'metric': {   'column': 'weekly_icu_admissions',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:weekly_icu_admissions',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '13196'}],
#     'meta': {   'format': 'longReadableNumber',
#                 'fullName': 'Count of weekly_icu_admissions_per_million',
#                 'name': 'Count'},
#     'metric': {   'column': 'weekly_icu_admissions_per_million',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT:weekly_icu_admissions_per_million',
#                   'metricType': 'COUNT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of aged_65_older',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'aged_65_older',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:aged_65_older',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of aged_70_older',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'aged_70_older',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:aged_70_older',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of cardiovasc_death_rate',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'cardiovasc_death_rate',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:cardiovasc_death_rate',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '6'}],
#     'meta': {   'fullName': 'Distinct value count of continent',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'continent',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:continent',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '527'}],
#     'meta': {   'fullName': 'Distinct value count of date',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'date',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:date',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of diabetes_prevalence',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'diabetes_prevalence',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:diabetes_prevalence',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of excess_mortality',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'excess_mortality',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:excess_mortality',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of extreme_poverty',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'extreme_poverty',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:extreme_poverty',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of female_smokers',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'female_smokers',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:female_smokers',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of gdp_per_capita',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'gdp_per_capita',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:gdp_per_capita',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '0'}],
#     'meta': {   'fullName': 'Distinct value count of handwashing_facilities',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'handwashing_facilities',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:handwashing_facilities',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'BIGINT',
#                           'partition': 'NP',
#                           'value': '5343'}],
#     'meta': {   'fullName': 'Distinct value count of hosp_patients',
#                 'name': 'Distinct value count'},
#     'metric': {   'column': 'hosp_patients',
#                   'dataType': 'BIGINT',
#                   'id': 'col_stats:COUNT_DISTINCT:hosp_patients',
#                   'metricType': 'COUNT_DISTINCT',
#                   'type': 'col_stats'},
#     'notExistingViews': [],
# ...
#     'meta': {   'fullName': 'Top 10 values of '
#                             'people_fully_vaccinated_per_hundred',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'people_fully_vaccinated_per_hundred',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:people_fully_vaccinated_per_hundred',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"2.42","7.11","3.94","10.08","11.62","6.05","7.2","6.1","9.74"]'}],
#     'meta': {   'fullName': 'Top 10 values of people_vaccinated',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'people_vaccinated',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:people_vaccinated',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"0.779","0.919","0.718","0.48","0.777","0.938","0.892","0.9159999999999999","0.9490000000000001"]'}],
#     'meta': {   'fullName': 'Top 10 values of people_vaccinated_per_hundred',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'people_vaccinated_per_hundred',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:people_vaccinated_per_hundred',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null]'}],
#     'meta': {   'fullName': 'Top 10 values of population',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'population',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:population',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null]'}],
#     'meta': {   'fullName': 'Top 10 values of population_density',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'population_density',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:population_density',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"3.053","1.845","2.063","1.726","4.321000000000001","7.441","6.89","4.455","8.353"]'}],
#     'meta': {   'fullName': 'Top 10 values of positive_rate',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'positive_rate',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:positive_rate',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"2.0","1.0","4.0","8.0","5.0","9.0","3.0","16.0","36.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of reproduction_rate',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'reproduction_rate',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:reproduction_rate',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null]'}],
#     'meta': {   'fullName': 'Top 10 values of stringency_index',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'stringency_index',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:stringency_index',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"17336.468999999997","18933.907","16277.671","12236.706","35938.373999999996","15469.207","15308.712","39002.223","54225.445999999996"]'}],
#     'meta': {   'fullName': 'Top 10 values of tests_per_case',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'tests_per_case',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:tests_per_case',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"0.2","0.5","0.1","0.7","1.0","2.0","1.3","1.5","2.5"]'}],
#     'meta': {   'fullName': 'Top 10 values of tests_units',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'tests_units',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:tests_units',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"1.0","4.0","3.0","721.0","2.0","509.0","27.0","18.0","19.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_cases',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_cases',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_cases',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"1.02","0.99","1.03","0.98","0.97","1.01","1.0","1.09","1.06"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_cases_per_million',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_cases_per_million',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_cases_per_million',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"1.0","3.0","2.0","7.0","10.0","4.0","15.0","6.0","21.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_deaths',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_deaths',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_deaths',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"0.0","0.019","0.986","3.432","0.998","0.995","7.985","0.245","3.89"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_deaths_per_million',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_deaths_per_million',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_deaths_per_million',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"60.19","50.93","71.3","52.78","47.22","65.74","56.48","80.56","64.81"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_tests',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_tests',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_tests',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"1.28932753E8","4.5195777E7","6.9799978E7","3.2971846E7","2.3816775E7","5.1269183E7","3.31002647E8","4.639847425E9","5.92072204E8"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_tests_per_thousand',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_tests_per_thousand',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_tests_per_thousand',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"152.783","191.032","109.861","85.755","103.95700000000001","85.99799999999999","261.899","151.089","233.07"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_vaccinations',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_vaccinations',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_vaccinations',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"76.88","72.58","81.32","75.05","76.68","77.29","72.06","71.72","61.58"]'}],
#     'meta': {   'fullName': 'Top 10 values of total_vaccinations_per_hundred',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'total_vaccinations_per_hundred',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:total_vaccinations_per_hundred',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"1.0","5.0","1179.0","19019.0","2.0","7.0","820.0","448.0","12272.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of weekly_hosp_admissions',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'weekly_hosp_admissions',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:weekly_hosp_admissions',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"0.0","1.0","3.0","30.0","2.0","534.0","780.0","90.0","288.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of '
#                             'weekly_hosp_admissions_per_million',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'weekly_hosp_admissions_per_million',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:weekly_hosp_admissions_per_million',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"0.0","8649.0","10702.0","11.0","841.0","846.0","6.0","118244.0","2601.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of weekly_icu_admissions',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'weekly_icu_admissions',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:weekly_icu_admissions',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {   'displayedAsMetric': False,
#     'lastValues': [   {   'computed': 1633716414663,
#                           'dataType': 'ARRAY',
#                           'partition': 'NP',
#                           'value': '[null,"0.0","8649.0","10702.0","2113080.0","841.0","5823245.0","24773.0","928107.0","225146.0"]'}],
#     'meta': {   'fullName': 'Top 10 values of '
#                             'weekly_icu_admissions_per_million',
#                 'name': 'Top 10 values'},
#     'metric': {   'column': 'weekly_icu_admissions_per_million',
#                   'dataType': 'ARRAY',
#                   'id': 'adv_col_stats:TOP10:weekly_icu_admissions_per_million',
#                   'metricType': 'TOP10',
#                   'type': 'adv_col_stats'},
#     'notExistingViews': [],
#     'partitionsWithValue': ['NP']}
# {'metric': {'metricType': 'TOP10', 'column': 'weekly_icu_admissions_per_million', 'type': 'adv_col_stats', 'id': 'adv_col_stats:TOP10:weekly_icu_admissions_per_million', 'dataType': 'ARRAY'}, 'meta': {'name': 'Top 10 values', 'fullName': 'Top 10 values of weekly_icu_admissions_per_million'}, 'partitionsWithValue': ['NP'], 'lastValues': [{'computed': 1633716414663, 'partition': 'NP', 'dataType': 'ARRAY', 'value': '[null,"0.0","8649.0","10702.0","2113080.0","841.0","5823245.0","24773.0","928107.0","225146.0"]'}], 'notExistingViews': [], 'displayedAsMetric': False}
