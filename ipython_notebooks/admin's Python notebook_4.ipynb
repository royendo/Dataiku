# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
client = dataiku.api_client()
projects =  client.get_project("EVERYTHING")
dataset = projects.get_dataset("SakeElasticSearch")
                               
mydataset_md = dataset.get_settings()
dataset.clear()           
settings  = mydataset_md.get_raw()

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': 'sakeelasticsearch',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
settings['params']['index'] = dataiku.get_custom_variables()["year"]

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': '2020',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
mydataset_md.save()

# %%
dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
# Out:
# ---------------------------------------------------------------------------
# DataikuException                          Traceback (most recent call last)
# <ipython-input-30-568901402849> in <module>
# ----> 1 dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/dataset.py in build(self, job_type, partitions, wait, no_fail)
#     288         jd.with_output(self.dataset_name, partition=partitions)
#     289         if wait:
# --> 290             return jd.start_and_wait()
#     291         else:
#     292             return jd.start()
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/project.py in start_and_wait(self, no_fail)
#    1715         job = self.start()
#    1716         waiter = DSSJobWaiter(job)
# -> 1717         waiter.wait(no_fail)
#    1718         return job
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/job.py in wait(self, no_fail)
#      63                     break
#      64                 else:
# ---> 65                     raise DataikuException("Job run did not finish. Status: %s" % (job_state))
#      66         return job_state
#
# DataikuException: Job run did not finish. Status: FAILED

# %%
import dataiku


temp = dataiku.get_custom_variables()['year']
new = int(temp) + 1
dataiku.set_custom_variables({'year':str(new)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3fe0063f22f9> in <module>
#       4 temp = dataiku.get_custom_variables()['year']
#       5 new = int(temp) + 1
# ----> 6 dataiku.set_custom_variables({'year':str(new)})
#
# AttributeError: module 'dataiku' has no attribute 'set_custom_variables'

# %%
import dataikuapi
host = "http://localhost:11200"
apiKey = "GrFWHV8ghdnHUmh3SI4M0jguBqfFC55x"
client = dataikuapi.DSSClient(host, apiKey)

# %%
projects = client.list_projects()

# %%
pp.pprint(projects)
# Out:
# [   {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {   'checklists': [   {   'createdOn': 0,
#                                                 'items': [   {   'createdBy': 'admin',
#                                                                  'createdOn': 1625592377906,
#                                                                  'done': True,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Create '
#                                                                          'the '
#                                                                          'project'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1625592377906,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Set '
#                                                                          'a '
#                                                                          'project '
#                                                                          'image '
#                                                                          '(click '
#                                                                          'on '
#                                                                          'the '
#                                                                          'color '
#                                                                          'next '
#                                                                          'to '
#                                                                          'the '
#                                                                          'project '
#                                                                          'title)'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1625592377906,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Import '
#                                                                          'your '
#                                                                          '[first '
#                                                                          'dataset](projects/AUDITLOGANALYSIS/datasets/new/)'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1625592377906,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Organize '
#                                                                          'your '
#                                                                          'work '
#                                                                          'by '
#                                                                          'replacing '
#                                                                          'this '
#                                                                          'with '
#                                                                          'a '
#                                                                          'real '
#                                                                          'todo'}],
#                                                 'title': "Your new project's "
#                                                          'Todo'}]},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1625592377905,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#f44336',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 6,
#         'isProjectAdmin': True,
#         'isProjectImg': False,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Audit Log Analysis',
#         'objectImgHash': 1774681275,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'AUDITLOGANALYSIS',
#         'projectType': 'REGULAR',
#         'shortDesc': 'The project *Audit Log Analysis* was created by '
#                      'Administrator on Jul 06th 2021',
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': ['imported'],
#         'tutorialProject': False,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1630678837706,
#                           'versionNumber': 2}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {   'checklists': [   {   'createdOn': 0,
#                                                 'items': [   {   'createdBy': 'admin',
#                                                                  'createdOn': 1623300289107,
#                                                                  'done': True,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Create '
#                                                                          'the '
#                                                                          'project'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1623300289107,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Set '
#                                                                          'a '
#                                                                          'project '
#                                                                          'image '
#                                                                          '(click '
#                                                                          'on '
#                                                                          'the '
#                                                                          'color '
#                                                                          'next '
#                                                                          'to '
#                                                                          'the '
#                                                                          'project '
#                                                                          'title)'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1623300289107,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Import '
#                                                                          'your '
#                                                                          '[first '
#                                                                          'dataset](projects/AUDITTEST/datasets/new/)'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1623300289107,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Organize '
#                                                                          'your '
#                                                                          'work '
#                                                                          'by '
#                                                                          'replacing '
#                                                                          'this '
#                                                                          'with '
#                                                                          'a '
#                                                                          'real '
#                                                                          'todo'}],
#                                                 'title': "Your new project's "
#                                                          'Todo'}]},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1623300289106,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#a0a0a0',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 4,
#         'isProjectAdmin': True,
#         'isProjectImg': False,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Audit Test',
#         'objectImgHash': 586019037,
#         'ownerDisplayName': 'user1',
#         'ownerLogin': 'user1',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'AUDITTEST',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'The project *Audit Test* was created by Administrator on '
#                      'Jun 10th 2021',
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': [],
#         'tutorialProject': False,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1630689336151,
#                           'versionNumber': 3}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {'checklists': []},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1605864413652,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#28aadd',
#         'description': 'Uploaded data originally acquired from the UCI ML '
#                        'Repositories [Online '
#                        'Retail](https://archive.ics.uci.edu/ml/datasets/Online+Retail) '
#                        'and [Online Retail II Data '
#                        'Set](https://archive.ics.uci.edu/ml/datasets/Online+Retail+II)\n',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 7,
#         'isProjectAdmin': True,
#         'isProjectImg': True,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Advanced Designer Assessment for Administrator',
#         'objectImgHash': 1623636865000,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'DKU_EXAM_ADV_DESIGNER',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'This project provides a starting point for the [Advanced '
#                      'Designer '
#                      'Assessment](https://academy.dataiku.com/advanced-designer-certificate).',
#         'showInitials': False,
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': [   'academy',
#                     'exam',
#                     'tutorial',
#                     'downloads',
#                     'section:Advanced Designer'],
#         'tutorialId': 'DKU_EXAM_ADV_DESIGNER',
#         'tutorialProject': True,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1623636868087,
#                           'versionNumber': 29}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {'checklists': []},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1592583992360,
#                            'versionNumber': 0},
#         'customFields': {   'gdpr_forbid_dataset_export': False,
#                             'gdpr_forbid_dataset_sharing': False,
#                             'gdpr_forbid_model_creation': False,
#                             'gdpr_forbid_uploaded_datasets': False},
#         'defaultImgColor': '#f44336',
#         'description': '# Welcome to the ML Practitioner Assessment project\n'
#                        '\n'
#                        '<p class="text-center">\n'
#                        '   <a '
#                        'href="https://academy.dataiku.com/ml-practitioner-certificate" '
#                        'target="_blank" class="btn btn-datasets-color '
#                        'btn-cta-big-mod"><i class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" />&nbsp;Learning Path '
#                        'Assessment\n'
#                        '  </a>\n'
#                        '</p>\n'
#                        '\n'
#                        'This project provides a starting point for completing '
#                        'the hands-on portion of the ML Practitioner '
#                        'assessment.',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 6,
#         'isProjectAdmin': True,
#         'isProjectImg': True,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'ML Practitioner Assessment for Administrator',
#         'objectImgHash': 1623195190000,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'DKU_EXAM_ML_PRACTITIONER',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'This project provides a starting point for the [ML '
#                      'Practitioner '
#                      'Assessment](https://academy.dataiku.com/ml-practitioner-certificate).',
#         'showInitials': False,
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': [   'exam',
#                     'downloads',
#                     'tutorial',
#                     'section:ML Practitioner',
#                     'academy'],
#         'tutorialId': 'DKU_EXAM_ML_PRACTITIONER',
#         'tutorialProject': True,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1625821145816,
#                           'versionNumber': 26}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {'checklists': []},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'customFields': {},
#         'defaultImgColor': '#f28c38',
#         'description': '_This project offers a slightly different look at the '
#                        'Haiku T-Shirt company from the '
#                        '[Tutorials](https://academy.dataiku.com/latest/tutorial/index.html)_\n'
#                        '\n'
#                        '<br/>\n'
#                        '# Revenue prediction\n'
#                        '\n'
#                        "In this project you'll learn how to predict the "
#                        'monthly revenue of new customers once they completed '
#                        'their first purchase.\n'
#                        'This is done by :\n'
#                        '\n'
#                        '1. Using historical CRM data mixed with users '
#                        'interactions on the web site to build a predictive '
#                        'model,\n'
#                        '2. Updating this model with the most recent data to '
#                        'get the best possible predictions,\n'
#                        '3. Use this up-to-date model to predict how much '
#                        'revenue new customers will generate this month.\n'
#                        '\n'
#                        '<br/>\n'
#                        '# Visit the sample project\n'
#                        '\n'
#                        '\n'
#                        '1. The Graphical Flow of the data and model '
#                        'processing.<br/>\n'
#                        '<p class="text-center">\n'
#                        '<a href="/projects/DKU_TSHIRTS/flow/"  class="btn '
#                        'btn-datasets-color btn-cta-big-mod"><i '
#                        'class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" '
#                        '/>&nbsp;Flow</a><br/><br/>\n'
#                        '</p>\n'
#                        '\n'
#                        '2. Insights related to customers and revenue '
#                        'prediction.\n'
#                        'Note that some charts requires the installation of the '
#                        '[Reverse '
#                        'Geocoding](https://www.dataiku.com/product/plugins/geoadmin/) '
#                        'plugin.\n'
#                        '<p class="text-center">\n'
#                        '<a href="/projects/DKU_TSHIRTS/dashboards/"  '
#                        'class="btn btn-datasets-color btn-cta-big-mod"><i '
#                        'class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" '
#                        '/>&nbsp;Dashboards</a><br/><br/>\n'
#                        '</p>\n'
#                        '\n'
#                        '\n'
#                        '3. Train a predictive model to learn about the key '
#                        'factors impacting revenue.\n'
#                        '<p class="text-center">\n'
#                        '<a href="/projects/DKU_TSHIRTS/analysis/xXTYPWEJ/"  '
#                        'class="btn btn-datasets-color btn-cta-big-mod"><i '
#                        'class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" />&nbsp;Machine learning '
#                        'analysis</a><br/><br/>\n'
#                        '</p>\n'
#                        '\n'
#                        '\n'
#                        '4. Deploy that Machine Learning Model to update it '
#                        "regularly and forecast new customers' revenue "
#                        'accurately.\n'
#                        '<p class="text-center">\n'
#                        '<a href="/projects/DKU_TSHIRTS/analysis/gPd2KlKo/"  '
#                        'class="btn btn-datasets-color btn-cta-big-mod"><i '
#                        'class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" />&nbsp;Machine learning '
#                        'models</a><br/><br/>\n'
#                        '</p>\n'
#                        '\n'
#                        '\n'
#                        '<br/>\n'
#                        '#More on this topic\n'
#                        '\n'
#                        '\n'
#                        '1.  REFERENCE : Understanding DSS visual grammar '
#                        '[http://doc.dataiku.com/dss/latest/flow/index.html?highlight=visual%20grammar](http://doc.dataiku.com/dss/latest/flow/index.html?highlight=visual%20grammar)\n'
#                        '2.  VIDEO : 15 minutes to Deploy your Predictive '
#                        'Application : '
#                        '[https://www.dataiku.com/learn/guide/free-training/deploy-predictive-application.html](https://www.dataiku.com/learn/guide/free-training/deploy-predictive-application.html)',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 1,
#         'isProjectAdmin': True,
#         'isProjectImg': True,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Dataiku TShirts for Administrator',
#         'objectImgHash': 1623978846000,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'DKU_TSHIRTS',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'This project offers a slightly different look at the '
#                      'Haiku T-Shirt company from the '
#                      '[Tutorials](https://academy.dataiku.com/latest/tutorial/index.html)',
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': ['sample_project', 'sample'],
#         'tutorialId': 'DKU_TSHIRTS',
#         'tutorialProject': True,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1623978848929,
#                           'versionNumber': 17}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {'checklists': []},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1591780554772,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#f28c38',
#         'description': '# Welcome to the Partitioned Models Tutorial\n'
#                        '\n'
#                        '<p class="text-center">\n'
#                        '   <a '
#                        'href="https://academy.dataiku.com/partitioned-models" '
#                        'target="_blank" class="btn btn-datasets-color '
#                        'btn-cta-big-mod"><i class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" />&nbsp;Learning Path\n'
#                        '  </a>\n'
#                        '</p>\n'
#                        '\n'
#                        'In this tutorial, you will create a partitioned '
#                        'machine learning model to predict how much time '
#                        '(minutes) a given flight will be delayed based on '
#                        'flight characteristics. ',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 8,
#         'isProjectAdmin': True,
#         'isProjectImg': True,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Partitioned Models (Tutorial) for Administrator',
#         'objectImgHash': 1623288580000,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'DKU_TUTORIAL_PARTITIONED_MODELS',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'Build a partitioned model using flight data from the '
#                      '[Bureau of Transportation Statistics, United States '
#                      'Department of Transportation](https://www.bts.gov).',
#         'showInitials': False,
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': [   'tutorial',
#                     'academy',
#                     'partitions',
#                     'machine learning',
#                     'section:ML Practitioner',
#                     'downloads'],
#         'tutorialId': 'DKU_TUTORIAL_PARTITIONED_MODELS',
#         'tutorialProject': True,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1623288582497,
#                           'versionNumber': 49}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {'checklists': []},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'customFields': {},
#         'defaultImgColor': '#28aadd',
#         'description': '# Partitions redispatch tutorial\n'
#                        '\n'
#                        '\n'
#                        '<p class="text-center">\n'
#                        '   <a '
#                        'href="https://academy.dataiku.com/partitions-course/513274" '
#                        'target="_blank" class="btn btn--contained '
#                        'btn-datasets-color btn--large">Start learning\n'
#                        '  </a>\n'
#                        '</p>\n'
#                        '\n'
#                        'In this tutorial, we will learn how to make a '
#                        'partitioned dataset from a non-partitioned dataset '
#                        'using the redispatch feature.',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 3,
#         'isProjectAdmin': True,
#         'isProjectImg': True,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Redispatch partitions (Tutorial) for Administrator',
#         'objectImgHash': 1625789331000,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'DKU_TUTORIAL_REDISPATCHPARTITIONS',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'Tutorial: How to redispatch data using partitions',
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': ['tutorial', 'section:Partitioning', 'downloads'],
#         'tutorialId': 'DKU_TUTORIAL_REDISPATCHPARTITIONS',
#         'tutorialProject': True,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1625789333357,
#                           'versionNumber': 19}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {   'checklists': [   {   'createdOn': 0,
#                                                 'id': 'd03589',
#                                                 'items': [   {   'createdBy': 'sean',
#                                                                  'createdOn': 1621256820043,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Go '
#                                                                          'to '
#                                                                          'Notebooks '
#                                                                          '(G+N) '
#                                                                          'and '
#                                                                          'open '
#                                                                          'the '
#                                                                          'Tutorial '
#                                                                          'Instructions'},
#                                                              {   'createdBy': 'sean',
#                                                                  'createdOn': 1621256829370,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Run '
#                                                                          'the '
#                                                                          'cells '
#                                                                          'there '
#                                                                          'one '
#                                                                          'at a '
#                                                                          'time.'}],
#                                                 'title': 'Todo list'}]},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1612965751838,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#28aadd',
#         'description': '# Welcome to the APIs in DSS Tutorial\n'
#                        '\n'
#                        '<p class="text-center">\n'
#                        '   <a href="https://academy.dataiku.com/apis-in-dss" '
#                        'target="_blank" class="btn btn-datasets-color '
#                        'btn-cta-big-mod"><i class="icon-dku-sample_project" '
#                        'class="btn-cta-big-mod-icon" />&nbsp;Go to the Course '
#                        'on Dataiku Academy\n'
#                        '  </a>\n'
#                        '</p>\n'
#                        '\n'
#                        'In this tutorial, you will begin manipulating DSS '
#                        'objects using the public API.\n',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 4,
#         'isProjectAdmin': True,
#         'isProjectImg': True,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
# ...
#         'tags': [],
#         'tutorialProject': False,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1623797749960,
#                           'versionNumber': 0}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {   'checklists': [   {   'createdOn': 0,
#                                                 'items': [   {   'createdBy': 'admin',
#                                                                  'createdOn': 1627451219902,
#                                                                  'done': True,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Create '
#                                                                          'the '
#                                                                          'project'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1627451219902,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Set '
#                                                                          'a '
#                                                                          'project '
#                                                                          'image '
#                                                                          '(click '
#                                                                          'on '
#                                                                          'the '
#                                                                          'color '
#                                                                          'next '
#                                                                          'to '
#                                                                          'the '
#                                                                          'project '
#                                                                          'title)'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1627451219902,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Import '
#                                                                          'your '
#                                                                          '[first '
#                                                                          'dataset](projects/SCENARIOPYTHONSTEP/datasets/new/)'},
#                                                              {   'createdBy': 'admin',
#                                                                  'createdOn': 1627451219902,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Organize '
#                                                                          'your '
#                                                                          'work '
#                                                                          'by '
#                                                                          'replacing '
#                                                                          'this '
#                                                                          'with '
#                                                                          'a '
#                                                                          'real '
#                                                                          'todo'}],
#                                                 'title': "Your new project's "
#                                                          'Todo'}]},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {'login': 'admin'},
#                            'lastModifiedOn': 1627451219901,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#28aadd',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 1,
#         'isProjectAdmin': True,
#         'isProjectImg': False,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Scenario Python Step',
#         'objectImgHash': 1060731986,
#         'ownerDisplayName': 'Administrator',
#         'ownerLogin': 'admin',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'SCENARIOPYTHONSTEP',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'The project *Scenario Python Step* was created by '
#                      'Administrator on Jul 28th 2021',
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': [],
#         'tutorialProject': False,
#         'versionTag': {   'lastModifiedBy': {'login': 'admin'},
#                           'lastModifiedOn': 1627451219901,
#                           'versionNumber': 0}},
#     {   'canExecuteApp': True,
#         'canExportDatasetsData': True,
#         'canManageAdditionalDashboardUsers': True,
#         'canManageDashboardAuthorizations': True,
#         'canManageExposedElements': True,
#         'canModerateDashboards': True,
#         'canReadDashboards': True,
#         'canReadProjectContent': True,
#         'canRunScenarios': True,
#         'canWriteDashboards': True,
#         'canWriteProjectContent': True,
#         'checklists': {   'checklists': [   {   'createdOn': 0,
#                                                 'items': [   {   'createdBy': 'colin.cunningham@saic.com',
#                                                                  'createdOn': 1629307057386,
#                                                                  'done': True,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Create '
#                                                                          'the '
#                                                                          'project'},
#                                                              {   'createdBy': 'colin.cunningham@saic.com',
#                                                                  'createdOn': 1629307057386,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Set '
#                                                                          'a '
#                                                                          'project '
#                                                                          'image '
#                                                                          '(click '
#                                                                          'on '
#                                                                          'the '
#                                                                          'color '
#                                                                          'next '
#                                                                          'to '
#                                                                          'the '
#                                                                          'project '
#                                                                          'title)'},
#                                                              {   'createdBy': 'colin.cunningham@saic.com',
#                                                                  'createdOn': 1629307057386,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Import '
#                                                                          'your '
#                                                                          '[first '
#                                                                          'dataset](projects/TEXTEXTRACTIONDEMO/datasets/new/)'},
#                                                              {   'createdBy': 'colin.cunningham@saic.com',
#                                                                  'createdOn': 1629307057386,
#                                                                  'done': False,
#                                                                  'stateChangedOn': 0,
#                                                                  'text': 'Organize '
#                                                                          'your '
#                                                                          'work '
#                                                                          'by '
#                                                                          'replacing '
#                                                                          'this '
#                                                                          'with '
#                                                                          'a '
#                                                                          'real '
#                                                                          'todo'}],
#                                                 'title': "Your new project's "
#                                                          'Todo'}]},
#         'commitMode': 'AUTO',
#         'contributors': [],
#         'creationTag': {   'lastModifiedBy': {   'login': 'colin.cunningham@saic.com'},
#                            'lastModifiedOn': 1629307057385,
#                            'versionNumber': 0},
#         'customFields': {},
#         'defaultImgColor': '#f44336',
#         'disableAutomaticTriggers': False,
#         'imgPattern': 2,
#         'isProjectAdmin': True,
#         'isProjectImg': False,
#         'metrics': {   'displayedState': {'columns': [], 'metrics': []},
#                        'engineConfig': {   'basic': {},
#                                            'dss': {   'active': True,
#                                                       'selection': {   'filter': {   'distinct': False,
#                                                                                      'enabled': False},
#                                                                        'latestPartitionsN': 1,
#                                                                        'maxReadUncompressedBytes': -1,
#                                                                        'maxRecords': -1,
#                                                                        'ordering': {   'enabled': False,
#                                                                                        'rules': [   ]},
#                                                                        'partitionSelectionMethod': 'ALL',
#                                                                        'samplingMethod': 'FULL',
#                                                                        'targetRatio': 0.02,
#                                                                        'useMemTable': False,
#                                                                        'withinFirstN': -1}},
#                                            'hive': {   'active': True,
#                                                        'extraConf': []},
#                                            'impala': {'active': True},
#                                            'padRunsWithMetrics': False,
#                                            'python': {},
#                                            'spark': {   'active': True,
#                                                         'extraConf': []},
#                                            'sql': {'active': True}},
#                        'probes': []},
#         'metricsChecks': {   'checks': [],
#                              'displayedState': {'checks': []},
#                              'runOnBuild': False},
#         'name': 'Intelligent Document Search',
#         'objectImgHash': 1736620237,
#         'ownerLogin': 'colin.cunningham@saic.com',
#         'projectAppType': 'REGULAR',
#         'projectKey': 'TEXTEXTRACTIONDEMO',
#         'projectStatus': 'Sandbox',
#         'projectType': 'REGULAR',
#         'shortDesc': 'The project *Text Extraction Demo* was created by Colin '
#                      'C on Aug 18th 2021',
#         'sparkPipelinesEnabled': False,
#         'sqlPipelinesEnabled': False,
#         'tags': [],
#         'tutorialProject': False,
#         'versionTag': {   'lastModifiedBy': {   'login': 'colin.cunningham@saic.com'},
#                           'lastModifiedOn': 1630514491062,
#                           'versionNumber': 1}}]
