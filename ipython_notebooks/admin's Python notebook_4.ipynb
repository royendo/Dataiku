# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
client = dataiku.api_client()
projects =  client.get_project("EVERYTHING")
dataset = projects.get_dataset("SakeElasticSearch")
                               
mydataset_md = dataset.get_settings()
dataset.clear()           
settings  = mydataset_md.get_raw()

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': 'sakeelasticsearch',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
settings['params']['index'] = dataiku.get_custom_variables()["year"]

# %%
pp.pprint(settings['params'])
# Out:
# {   'connection': 'ElasticSearch',
#     'frameSize': 10000,
#     'index': '2020',
#     'notReadyIfEmpty': False,
#     'partitioned': False,
#     'type': 'sakeelasticsearch'}

# %%
mydataset_md.save()

# %%
dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
# Out:
# ---------------------------------------------------------------------------
# DataikuException                          Traceback (most recent call last)
# <ipython-input-30-568901402849> in <module>
# ----> 1 dataset.build(job_type='NON_RECURSIVE_FORCED_BUILD', partitions=None, wait=True, no_fail=False)
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/dataset.py in build(self, job_type, partitions, wait, no_fail)
#     288         jd.with_output(self.dataset_name, partition=partitions)
#     289         if wait:
# --> 290             return jd.start_and_wait()
#     291         else:
#     292             return jd.start()
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/project.py in start_and_wait(self, no_fail)
#    1715         job = self.start()
#    1716         waiter = DSSJobWaiter(job)
# -> 1717         waiter.wait(no_fail)
#    1718         return job
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/job.py in wait(self, no_fail)
#      63                     break
#      64                 else:
# ---> 65                     raise DataikuException("Job run did not finish. Status: %s" % (job_state))
#      66         return job_state
#
# DataikuException: Job run did not finish. Status: FAILED

# %%
import dataiku


temp = dataiku.get_custom_variables()['year']
new = int(temp) + 1
dataiku.set_custom_variables({'year':str(new)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3fe0063f22f9> in <module>
#       4 temp = dataiku.get_custom_variables()['year']
#       5 new = int(temp) + 1
# ----> 6 dataiku.set_custom_variables({'year':str(new)})
#
# AttributeError: module 'dataiku' has no attribute 'set_custom_variables'

# %%
import dataikuapi
host = "http://localhost:11200"
apiKey = "GrFWHV8ghdnHUmh3SI4M0jguBqfFC55x"
client = dataikuapi.DSSClient(host, apiKey)
#client = dataiku.api_client()

# %%
projects = client.list_project_keys()

# %%
import dataikuapi
host = "http://localhost:11200"
apiKey = "GrFWHV8ghdnHUmh3SI4M0jguBqfFC55x"
client = dataikuapi.DSSClient(host, apiKey)
#client = dataiku.api_client()
projects = client.list_project_keys()
for project in projects:
    pp.pprint(project)
    jobs = client.get_project(project).list_jobs()
    
    for job in jobs:
        if (job['endTime']==0 and ['stableState'] == False,):
            print(job['def']['name'])
            print(job)
# Out:
# 'AUDITLOGANALYSIS'
# Build d (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_d__NP__2021-09-02T17-48-20.379', 'name': 'Build d (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_d', 'initiationTimestamp': 1630604900379, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'd', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'ABORTED', 'warningsCount': 0, 'startTime': 1630604900530, 'endTime': 1630604920574, 'kernelPid': 0}
# Build d (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_d__NP__2021-09-02T17-47-45.492', 'name': 'Build d (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_d', 'initiationTimestamp': 1630604865492, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'd', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1630604870083, 'endTime': 1630604873183, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_prepared__NP__2021-09-01T15-25-56.231', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1630509956231, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509956402, 'endTime': 1630509959499, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_prepared__NP__2021-09-01T15-21-13.772', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1630509673772, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509673906, 'endTime': 1630509676968, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_prepared__NP__2021-09-01T15-20-45.796', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1630509645796, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509645948, 'endTime': 1630509649033, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_prepared__NP__2021-09-01T15-18-16.810', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1630509496810, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509496948, 'endTime': 1630509500038, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_prepared__NP__2021-09-01T15-17-52.501', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1630509472501, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509472639, 'endTime': 1630509476222, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_prepared__NP__2021-09-01T15-15-21.754', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1630509321754, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509321884, 'endTime': 1630509325462, 'kernelPid': 0}
# Build audit_filtered (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_filtered__NP__2021-09-01T15-13-53.255', 'name': 'Build audit_filtered (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_filtered', 'initiationTimestamp': 1630509233255, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_filtered', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509233409, 'endTime': 1630509238956, 'kernelPid': 0}
# Build audit_filtered (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_filtered__NP__2021-09-01T15-13-20.096', 'name': 'Build audit_filtered (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_filtered', 'initiationTimestamp': 1630509200096, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_filtered', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630509200222, 'endTime': 1630509203768, 'kernelPid': 0}
# Build apicall_prepared (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_apicall_prepared__NP__2021-09-01T15-09-16.795', 'name': 'Build apicall_prepared (NP)', 'initiator': 'admin', 'initiationTimestamp': 1630508956795, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'apicall_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630508956969, 'endTime': 1630508969219, 'kernelPid': 0}
# Build apicall_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_apicall_prepared__NP__2021-09-01T15-07-11.013', 'name': 'Build apicall_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_apicall_prepared', 'initiationTimestamp': 1630508831013, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'apicall_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630508831175, 'endTime': 1630508834253, 'kernelPid': 0}
# Build apicall_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_apicall_prepared__NP__2021-09-01T15-03-35.426', 'name': 'Build apicall_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_apicall_prepared', 'initiationTimestamp': 1630508615426, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'apicall_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630508615630, 'endTime': 1630508618731, 'kernelPid': 0}
# Build CRU (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_CRU__NP__2021-09-01T15-01-06.991', 'name': 'Build CRU (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_log', 'initiationTimestamp': 1630508466991, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630508467227, 'endTime': 1630508473936, 'kernelPid': 0}
# Build generic_audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_audit_prepared__NP__2021-08-27T14-08-27.094', 'name': 'Build generic_audit_prepared (NP)', 'initiator': 'admin', 'initiationTimestamp': 1630073307094, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630073307196, 'endTime': 1630073319434, 'kernelPid': 0}
# Build auth_failure_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_auth_failure_prepared__NP__2021-08-27T13-55-38.626', 'name': 'Build auth_failure_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_auth_failure_prepared', 'initiationTimestamp': 1630072538626, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630072538707, 'endTime': 1630072540138, 'kernelPid': 0}
# Build generic_failure_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_failure_prepared__NP__2021-08-27T13-52-37.341', 'name': 'Build generic_failure_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_generic_failure_prepared', 'initiationTimestamp': 1630072357341, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_failure_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630072357449, 'endTime': 1630072359422, 'kernelPid': 0}
# Build auth_failure_prepared (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_auth_failure_prepared__NP__2021-08-27T13-40-22.963', 'name': 'Build auth_failure_prepared (NP)', 'initiator': 'admin', 'initiationTimestamp': 1630071622963, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1630071623168, 'endTime': 1630071634478, 'kernelPid': 0}
# Build unique_msg_type (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_unique_msg_type__NP__2021-08-24T13-56-12.566', 'name': 'Build unique_msg_type (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_generic_audit_prepared_by_message_msgType_1', 'initiationTimestamp': 1629813372566, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'unique_msg_type', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1629813377163, 'endTime': 1629813379491, 'kernelPid': 0}
# Build generic_audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_audit_prepared__NP__2021-08-24T13-56-05.522', 'name': 'Build generic_audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_generic_audit_prepared', 'initiationTimestamp': 1629813365522, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1629813370096, 'endTime': 1629813374045, 'kernelPid': 0}
# Build generic_audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_audit_prepared__NP__2021-08-24T13-55-55.586', 'name': 'Build generic_audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_generic_audit_prepared', 'initiationTimestamp': 1629813355586, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1629813359621, 'endTime': 1629813362965, 'kernelPid': 0}
# Build CRU (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_CRU__NP__2021-08-24T13-55-02.530', 'name': 'Build CRU (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_log', 'initiationTimestamp': 1629813302530, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1629813307090, 'endTime': 1629813312479, 'kernelPid': 0}
# Build generic_failure_prepared (NP), settings_related (NP), project_related (NP), api (NP), other (NP), download_related (NP), generic_loginout (NP), auth_failure_prepared (NP), cru_ (NP), unique_msg_
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_failure_prepared__NP___settings_related__NP___project_related__NP___api__NP___other__NP___download_related__NP___generic_loginout__NP___auth_failure_prepared__NP___cru___NP___unique_msg__2021-08-24T13-51-51.850', 'name': 'Build generic_failure_prepared (NP), settings_related (NP), project_related (NP), api (NP), other (NP), download_related (NP), generic_loginout (NP), auth_failure_prepared (NP), cru_ (NP), unique_msg_', 'initiator': 'admin', 'initiationTimestamp': 1629813111850, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'settings_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'project_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'api', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'other', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'download_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_loginout', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'cru_', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'unique_msg_type', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU_prepared_windows_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_2_login', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'login_related_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1629813116477, 'endTime': 1629813132712, 'kernelPid': 0}
# Build generic_loginout (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_loginout__NP__2021-07-14T07-37-57.090', 'name': 'Build generic_loginout (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_generic_loginout', 'initiationTimestamp': 1626248277090, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_loginout', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626248277182, 'endTime': 1626248278565, 'kernelPid': 0}
# Build audit_2_login (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_2_login__NP__2021-07-14T07-36-17.626', 'name': 'Build audit_2_login (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_2_login', 'initiationTimestamp': 1626248177626, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_2_login', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626248177739, 'endTime': 1626248180588, 'kernelPid': 0}
# Build CRU (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_CRU__NP__2021-07-14T07-32-47.664', 'name': 'Build CRU (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_log', 'initiationTimestamp': 1626247967664, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626247967813, 'endTime': 1626247971840, 'kernelPid': 0}
# Build audit_log (NP), generic_failure_prepared (NP), settings_related (NP), project_related (NP), api (NP), other (NP), download_related (NP), generic_loginout (NP), auth_failure_prepared (NP), cru_ (
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_log__NP___generic_failure_prepared__NP___settings_related__NP___project_related__NP___api__NP___other__NP___download_related__NP___generic_loginout__NP___auth_failure_prepared__NP___cru____2021-07-14T07-30-30.524', 'name': 'Build audit_log (NP), generic_failure_prepared (NP), settings_related (NP), project_related (NP), api (NP), other (NP), download_related (NP), generic_loginout (NP), auth_failure_prepared (NP), cru_ (', 'initiator': 'admin', 'initiationTimestamp': 1626247830524, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_log', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'settings_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'project_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'api', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'other', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'download_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_loginout', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'cru_', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'unique_msg_type', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU_prepared_windows_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'login_related_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626247830623, 'endTime': 1626247841073, 'kernelPid': 0}
# Build generic_failure_prepared (NP), settings_related (NP), project_related (NP), api (NP), other (NP), download_related (NP), generic_loginout (NP), auth_failure_prepared (NP), cru_ (NP), unique_msg_
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_failure_prepared__NP___settings_related__NP___project_related__NP___api__NP___other__NP___download_related__NP___generic_loginout__NP___auth_failure_prepared__NP___cru___NP___unique_msg__2021-07-14T07-27-29.804', 'name': 'Build generic_failure_prepared (NP), settings_related (NP), project_related (NP), api (NP), other (NP), download_related (NP), generic_loginout (NP), auth_failure_prepared (NP), cru_ (NP), unique_msg_', 'initiator': 'admin', 'initiationTimestamp': 1626247649804, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'settings_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'project_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'api', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'other', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'download_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_loginout', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'cru_', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'unique_msg_type', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU_prepared_windows_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'login_related_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626247649911, 'endTime': 1626247662852, 'kernelPid': 0}
# Build generic_loginout (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic_loginout__NP__2021-07-14T07-22-28.563', 'name': 'Build generic_loginout (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_generic_loginout', 'initiationTimestamp': 1626247348563, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_loginout', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626247348650, 'endTime': 1626247350018, 'kernelPid': 0}
# Build generic (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic__NP__2021-07-14T07-18-50.546', 'name': 'Build generic (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_2021_07_14', 'initiationTimestamp': 1626247130546, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626247130658, 'endTime': 1626247132069, 'kernelPid': 0}
# Build generic (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_generic__NP__2021-07-14T07-17-10.547', 'name': 'Build generic (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_2021_07_14', 'initiationTimestamp': 1626247030547, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626247030695, 'endTime': 1626247032143, 'kernelPid': 0}
# Build auth_failure_prepared (NP), audit_log (NP), generic_failure_prepared (NP), settings_related (NP), unique_msg_type (NP), CRU_prepared_windows_prepared (NP), project_related (NP), login_related_pr
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_auth_failure_prepared__NP___audit_log__NP___generic_failure_prepared__NP___settings_related__NP___unique_msg_type__NP___CRU_prepared_windows_prepared__NP___project_related__NP___login_related_pr_2021-07-14T07-12-54.052', 'name': 'Build auth_failure_prepared (NP), audit_log (NP), generic_failure_prepared (NP), settings_related (NP), unique_msg_type (NP), CRU_prepared_windows_prepared (NP), project_related (NP), login_related_pr', 'initiator': 'admin', 'initiationTimestamp': 1626246774052, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_log', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'settings_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'unique_msg_type', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU_prepared_windows_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'project_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'login_related_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'download_related', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626246774164, 'endTime': 1626246778538, 'kernelPid': 0}
# Build audit_log_filtered_with_date (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_audit_log_filtered_with_date__NP__2021-07-14T07-12-29.301', 'name': 'Build audit_log_filtered_with_date (NP)', 'initiator': 'admin', 'initiationTimestamp': 1626246749301, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'audit_log_filtered_with_date', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626246749536, 'endTime': 1626246751038, 'kernelPid': 0}
# Build auth_failure_prepared (NP), generic_failure_prepared (NP), settings_related (NP), unique_msg_type (NP), CRU_prepared_windows_prepared (NP), project_related (NP), login_related_prepared (NP), dow
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITLOGANALYSIS', 'id': 'Build_auth_failure_prepared__NP___generic_failure_prepared__NP___settings_related__NP___unique_msg_type__NP___CRU_prepared_windows_prepared__NP___project_related__NP___login_related_prepared__NP___dow_2021-07-09T07-45-48.332', 'name': 'Build auth_failure_prepared (NP), generic_failure_prepared (NP), settings_related (NP), unique_msg_type (NP), CRU_prepared_windows_prepared (NP), project_related (NP), login_related_prepared (NP), dow', 'initiator': 'admin', 'initiationTimestamp': 1625816748332, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'auth_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'generic_failure_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'settings_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'unique_msg_type', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'CRU_prepared_windows_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'project_related', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'login_related_prepared', 'targetPartition': 'NP'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITLOGANALYSIS', 'targetDataset': 'download_related', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1625816762535, 'endTime': 1625816774942, 'kernelPid': 0}
# 'AUDITTEST'
# Build d (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_d__NP__2021-08-10T01-26-15.076', 'name': 'Build d (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1628558775076, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'd', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1628558775165, 'endTime': 1628558776550, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser_prepared (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser_prepared__NP__2021-08-10T01-25-12.729', 'name': 'Build audit_prepared_by_messageauthUser_prepared (NP)', 'initiator': 'admin', 'initiationTimestamp': 1628558712729, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1628558712862, 'endTime': 1628558716844, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser_prepared__NP__2021-06-17T09-24-46.664', 'name': 'Build audit_prepared_by_messageauthUser_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser_prepared', 'initiationTimestamp': 1623921886664, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623921886757, 'endTime': 1623921888117, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser_prepared (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser_prepared__NP__2021-06-17T09-22-12.544', 'name': 'Build audit_prepared_by_messageauthUser_prepared (NP)', 'initiator': 'admin', 'initiationTimestamp': 1623921732544, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623921732614, 'endTime': 1623921735048, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-17T09-21-43.305', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623921703305, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623921703480, 'endTime': 1623921704838, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-17T09-06-23.258', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623920783258, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623920783433, 'endTime': 1623920784895, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser_prepared__NP__2021-06-10T06-01-03.842', 'name': 'Build audit_prepared_by_messageauthUser_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser_prepared', 'initiationTimestamp': 1623304863842, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304863916, 'endTime': 1623304865310, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T06-00-03.349', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'initiationTimestamp': 1623304803349, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304816865, 'endTime': 1623304818810, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared__NP__2021-06-10T05-59-49.833', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1623304789833, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304789898, 'endTime': 1623304791238, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T05-59-04.579', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623304744579, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304744635, 'endTime': 1623304745963, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T05-57-59.798', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623304679798, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304679853, 'endTime': 1623304681180, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T05-57-06.693', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623304626693, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304626750, 'endTime': 1623304628058, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T05-56-39.252', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623304599252, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304599313, 'endTime': 1623304600116, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T05-55-55.452', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623304555452, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304555512, 'endTime': 1623304556336, 'kernelPid': 0}
# Build audit_prepared_by_messageauthUser (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_by_messageauthUser__NP__2021-06-10T05-55-11.698', 'name': 'Build audit_prepared_by_messageauthUser (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_by_messageauthUser', 'initiationTimestamp': 1623304511698, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_by_messageauthUser', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304511759, 'endTime': 1623304513057, 'kernelPid': 0}
# Build audit_prepared_distinct (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared_distinct__NP__2021-06-10T05-53-57.018', 'name': 'Build audit_prepared_distinct (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared_distinct', 'initiationTimestamp': 1623304437018, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared_distinct', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304437075, 'endTime': 1623304437899, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared__NP__2021-06-10T05-53-17.881', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1623304397881, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304397938, 'endTime': 1623304399237, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared__NP__2021-06-10T05-51-48.207', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1623304308207, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304308273, 'endTime': 1623304309647, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared__NP__2021-06-10T05-50-11.797', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_audit_prepared', 'initiationTimestamp': 1623304211797, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623304211867, 'endTime': 1623304213809, 'kernelPid': 0}
# Build New, Old
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_New__Old_2021-06-10T04-49-44.122', 'name': 'Build New, Old', 'initiator': 'admin', 'initiationTimestamp': 1623300584122, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'New'}, {'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'Old'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623300584183, 'endTime': 1623300602199, 'kernelPid': 0}
# Build audit_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_audit_prepared__NP__2021-06-10T04-49-19.093', 'name': 'Build audit_prepared (NP)', 'initiator': 'admin', 'initiationTimestamp': 1623300559093, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'audit_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623300572137, 'endTime': 1623300574002, 'kernelPid': 0}
# Build New (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'AUDITTEST', 'id': 'Build_New__NP__2021-06-10T04-49-07.760', 'name': 'Build New (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'split_audit_prepared', 'initiationTimestamp': 1623300547760, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'AUDITTEST', 'targetDataset': 'New', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1623300547859, 'endTime': 1623300548792, 'kernelPid': 0}
# 'DKU_EXAM_ADV_DESIGNER'
# Build Online_Retail_Distinct_by_year (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'DKU_EXAM_ADV_DESIGNER', 'id': 'Build_Online_Retail_Distinct_by_year__NP__2021-06-15T00-12-12.876', 'name': 'Build Online_Retail_Distinct_by_year (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_Online_Retail_Distinct_by_year', 'initiationTimestamp': 1623715932876, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'DKU_EXAM_ADV_DESIGNER', 'targetDataset': 'Online_Retail_Distinct_by_year', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623715946199, 'endTime': 1623715952149, 'kernelPid': 0}
# Build Online_Retail_Windowed (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'DKU_EXAM_ADV_DESIGNER', 'id': 'Build_Online_Retail_Windowed__NP__2021-06-14T23-51-35.132', 'name': 'Build Online_Retail_Windowed (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_Online_Retail_to_2010_Partitioned_windows_1', 'initiationTimestamp': 1623714695132, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'DKU_EXAM_ADV_DESIGNER', 'targetDataset': 'Online_Retail_Windowed', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1623714708947, 'endTime': 1623714710258, 'kernelPid': 0}
# Build Online_Retail_to_2010_Partitioned_windows (84077)
# ...
# sched_build
# {'stableState': True, 'def': {'type': 'RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'sched_build_2021-07-30T08-21-36.453', 'name': 'sched_build', 'initiator': 'admin', 'triggeredFrom': 'SCHEDULER', 'initiationTimestamp': 1627633296453, 'mailNotification': False, 'outputs': [{'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'CoronaSync', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627633310351, 'endTime': 1627633342032, 'scenarioProjectKey': 'EVERYTHING', 'scenarioId': '24811', 'stepId': 'build_0_true_d_CoronaSync', 'scenarioRunId': '2021-07-30-17-21-36-397', 'stepRunId': '2021-07-30-17-21-36-448', 'kernelPid': 0}
# sched_build
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'EVERYTHING', 'id': 'sched_build_2021-07-30T08-15-39.139', 'name': 'sched_build', 'initiator': 'admin', 'triggeredFrom': 'SCHEDULER', 'initiationTimestamp': 1627632939139, 'mailNotification': False, 'outputs': [{'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'CoronaSync', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627632952772, 'endTime': 1627632953363, 'scenarioProjectKey': 'EVERYTHING', 'scenarioId': '24811', 'stepId': 'build_0_true_d_CoronaSync', 'scenarioRunId': '2021-07-30-17-15-39-068', 'stepRunId': '2021-07-30-17-15-39-131', 'kernelPid': 0}
# sched_build
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'EVERYTHING', 'id': 'sched_build_2021-07-30T08-12-44.869', 'name': 'sched_build', 'initiator': 'admin', 'triggeredFrom': 'SCHEDULER', 'initiationTimestamp': 1627632764869, 'mailNotification': False, 'outputs': [{'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'CoronaSync', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627632778545, 'endTime': 1627632804972, 'scenarioProjectKey': 'EVERYTHING', 'scenarioId': '24811', 'stepId': 'build_0_true_d_CoronaSync', 'scenarioRunId': '2021-07-30-17-12-44-804', 'stepRunId': '2021-07-30-17-12-44-860', 'kernelPid': 0}
# Build CoronaSync (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_CoronaSync__NP__2021-07-30T08-12-10.710', 'name': 'Build CoronaSync (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_CoronaSync', 'initiationTimestamp': 1627632730710, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'CoronaSync', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627632744670, 'endTime': 1627632777719, 'kernelPid': 0}
# Build FITNESS_filtered (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_FITNESS_filtered__NP__2021-07-30T02-14-38.357', 'name': 'Build FITNESS_filtered (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_FITNESS_filtered', 'initiationTimestamp': 1627611278357, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'FITNESS_filtered', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627611278956, 'endTime': 1627611280784, 'kernelPid': 0}
# Build sakePostGreSQL_prepared_1 (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_sakePostGreSQL_prepared_1__NP__2021-07-29T04-48-06.903', 'name': 'Build sakePostGreSQL_prepared_1 (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_sakePostGreSQL_prepared_1', 'initiationTimestamp': 1627534086903, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'sakePostGreSQL_prepared_1', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627534086998, 'endTime': 1627534089108, 'kernelPid': 0}
# Build sakePostGreSQL_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_sakePostGreSQL_prepared__NP__2021-07-29T04-46-32.299', 'name': 'Build sakePostGreSQL_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_sakePostGreSQL_prepared', 'initiationTimestamp': 1627533992299, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'sakePostGreSQL_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627533992383, 'endTime': 1627533995874, 'kernelPid': 0}
# Build sakePostGreSQL_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_sakePostGreSQL_prepared__NP__2021-07-29T04-46-16.438', 'name': 'Build sakePostGreSQL_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_sakePostGreSQL_prepared', 'initiationTimestamp': 1627533976438, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'sakePostGreSQL_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1627533976764, 'endTime': 1627533979468, 'kernelPid': 0}
# Build ToS3Bucket (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_ToS3Bucket__NP__2021-07-29T00-10-51.455', 'name': 'Build ToS3Bucket (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_tqcjRuqM', 'initiationTimestamp': 1627517451455, 'mailNotification': False, 'outputs': [{'type': 'MANAGED_FOLDER', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'tqcjRuqM', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1627517451532, 'endTime': 1627517455693, 'kernelPid': 0}
# Build ToS3Bucket (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_ToS3Bucket__NP__2021-07-29T00-09-56.402', 'name': 'Build ToS3Bucket (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_tqcjRuqM', 'initiationTimestamp': 1627517396402, 'mailNotification': False, 'outputs': [{'type': 'MANAGED_FOLDER', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'tqcjRuqM', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627517396794, 'endTime': 1627517407460, 'kernelPid': 0}
# Build SakeMongo (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SakeMongo__NP__2021-07-28T02-32-51.889', 'name': 'Build SakeMongo (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SakeMongo', 'initiationTimestamp': 1627439571889, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SakeMongo', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 122, 'startTime': 1627439572025, 'endTime': 1627439579590, 'kernelPid': 0}
# Build SakeOracle (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SakeOracle__NP__2021-07-28T02-30-07.854', 'name': 'Build SakeOracle (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SakeOracle', 'initiationTimestamp': 1627439407854, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SakeOracle', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 122, 'startTime': 1627439407973, 'endTime': 1627439420024, 'kernelPid': 0}
# Build sakePostGreSQL (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_sakePostGreSQL__NP__2021-07-28T02-29-00.884', 'name': 'Build sakePostGreSQL (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_sakePostGreSQL', 'initiationTimestamp': 1627439340884, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'sakePostGreSQL', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 122, 'startTime': 1627439341019, 'endTime': 1627439343994, 'kernelPid': 0}
# Build SakeMySQL (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SakeMySQL__NP__2021-07-28T02-17-59.768', 'name': 'Build SakeMySQL (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SakeMySQL', 'initiationTimestamp': 1627438679768, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SakeMySQL', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1627438679861, 'endTime': 1627438681380, 'kernelPid': 0}
# Build SakeMySQL (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SakeMySQL__NP__2021-07-28T02-14-55.120', 'name': 'Build SakeMySQL (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SakeMySQL', 'initiationTimestamp': 1627438495120, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SakeMySQL', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1627438495238, 'endTime': 1627438496778, 'kernelPid': 0}
# Build SakeMySQL (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SakeMySQL__NP__2021-07-28T02-06-24.123', 'name': 'Build SakeMySQL (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SakeMySQL', 'initiationTimestamp': 1627437984123, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SakeMySQL', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'FAILED', 'warningsCount': 0, 'startTime': 1627437984238, 'endTime': 1627437985670, 'kernelPid': 0}
# Build SakeS3_avro (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SakeS3_avro__NP__2021-07-28T02-05-38.012', 'name': 'Build SakeS3_avro (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SakeS3_avro', 'initiationTimestamp': 1627437938012, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SakeS3_avro', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 122, 'startTime': 1627437951862, 'endTime': 1627437982079, 'kernelPid': 0}
# Build SaketoS3__csv (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_SaketoS3__csv__NP__2021-07-28T02-04-59.952', 'name': 'Build SaketoS3__csv (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_SaketoS3__csv', 'initiationTimestamp': 1627437899952, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'SaketoS3__csv', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 122, 'startTime': 1627437900120, 'endTime': 1627437926131, 'kernelPid': 0}
# Build Corona1_partitioned (2021)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_Corona1_partitioned__2021__2021-07-27T23-34-47.539', 'name': 'Build Corona1_partitioned (2021)', 'initiator': 'admin', 'initiationTimestamp': 1627428887539, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'Corona1_partitioned', 'targetPartition': '2021'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627428888016, 'endTime': 1627428897843, 'kernelPid': 0}
# Build FITNESS_checks (NP)
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'EVERYTHING', 'id': 'Build_FITNESS_checks__NP__2021-07-19T07-51-38.997', 'name': 'Build FITNESS_checks (NP)', 'initiator': 'admin', 'initiationTimestamp': 1626681098997, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'FITNESS_checks', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626681114996, 'endTime': 1626681115334, 'kernelPid': 0}
# sched_build
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'EVERYTHING', 'id': 'sched_build_2021-07-14T23-11-53.802', 'name': 'sched_build', 'initiator': 'admin', 'triggeredFrom': 'SCHEDULER', 'initiationTimestamp': 1626304313802, 'mailNotification': False, 'outputs': [{'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'Corona_MySQL', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626304314300, 'endTime': 1626304324986, 'scenarioProjectKey': 'EVERYTHING', 'scenarioId': 'Community_sync_automation', 'stepId': 'build_0_true_d_Corona_MySQL', 'scenarioRunId': '2021-07-15-08-11-53-691', 'stepRunId': '2021-07-15-08-11-53-790', 'kernelPid': 0}
# sched_build
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'EVERYTHING', 'id': 'sched_build_2021-07-14T01-01-27.136', 'name': 'sched_build', 'initiator': 'admin', 'triggeredFrom': 'SCHEDULER', 'initiationTimestamp': 1626224487136, 'mailNotification': False, 'outputs': [{'targetDatasetProjectKey': 'EVERYTHING', 'targetDataset': 'Corona_MySQL', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1626224501667, 'endTime': 1626224512258, 'scenarioProjectKey': 'EVERYTHING', 'scenarioId': 'Community_sync_automation', 'stepId': 'build_1_true_d_Corona_MySQL', 'scenarioRunId': '2021-07-14-10-01-27-016', 'stepRunId': '2021-07-14-10-01-27-120', 'kernelPid': 0}
# 'MANAGEDFOLDERS'
# 'SCENARIOPYTHONSTEP'
# sched_build
# {'stableState': True, 'def': {'type': 'RECURSIVE_BUILD', 'projectKey': 'SCENARIOPYTHONSTEP', 'id': 'sched_build_2021-07-28T05-50-00.399', 'name': 'sched_build', 'initiator': 'admin', 'triggeredFrom': 'SCHEDULER', 'initiationTimestamp': 1627451400399, 'mailNotification': False, 'outputs': [{'targetDatasetProjectKey': 'SCENARIOPYTHONSTEP', 'targetDataset': 'FITNESS_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627451400482, 'endTime': 1627451400912, 'scenarioProjectKey': 'SCENARIOPYTHONSTEP', 'scenarioId': 'Run', 'stepId': 'build_0_true_d_FITNESS_prepared', 'scenarioRunId': '2021-07-28-14-50-00-367', 'stepRunId': '2021-07-28-14-50-00-392', 'kernelPid': 0}
# Build FITNESS_prepared (NP)
# {'stableState': True, 'def': {'type': 'NON_RECURSIVE_FORCED_BUILD', 'projectKey': 'SCENARIOPYTHONSTEP', 'id': 'Build_FITNESS_prepared__NP__2021-07-28T05-49-11.402', 'name': 'Build FITNESS_prepared (NP)', 'initiator': 'admin', 'triggeredFrom': 'RECIPE', 'recipe': 'compute_FITNESS_prepared', 'initiationTimestamp': 1627451351402, 'mailNotification': False, 'outputs': [{'type': 'DATASET', 'targetDatasetProjectKey': 'SCENARIOPYTHONSTEP', 'targetDataset': 'FITNESS_prepared', 'targetPartition': 'NP'}], 'refreshHiveMetastore': True}, 'state': 'DONE', 'warningsCount': 0, 'startTime': 1627451351796, 'endTime': 1627451355513, 'kernelPid': 0}
# 'TEXTEXTRACTIONDEMO'

# %%
import dataiku
import time

client = dataiku.api_client()
projects = client.list_project_keys()
running = True


while running == True:
    running = False
    #time.sleep(60)
    for project in projects:
        projectjob = client.get_project(project)
        jobs = projectjob.list_jobs()
        for job in jobs:
            if (job['endTime']==0):
                running = True
                print("Jobs still running:" + job['def']['name'])
print("No Jobs running")
# Out:
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# Jobs still running:Build Fastparquetdataset (NP)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d7702ea1488f> in <module>
#      12     for project in projects:
#      13         projectjob = client.get_project(project)
# ---> 14         jobs = projectjob.list_jobs()
#      15         for job in jobs:
#      16             if (job['endTime']==0):
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dss/project.py in list_jobs(self)
#     809         """
#     810         return self.client._perform_json(
# --> 811             "GET", "/projects/%s/jobs/" % self.project_key)
#     812
#     813     def get_job(self, id):
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dssclient.py in _perform_json(self, method, path, params, body, files, raw_body)
#    1035
#    1036     def _perform_json(self, method, path, params=None, body=None,files=None, raw_body=None):
# -> 1037         return self._perform_http(method, path,  params=params, body=body, files=files, stream=False, raw_body=raw_body).json()
#    1038
#    1039     def _perform_raw(self, method, path, params=None, body=None,files=None, raw_body=None):
#
# /opt/dataiku/install/dataiku-dss-9.0.3-osx/python/dataikuapi/dssclient.py in _perform_http(self, method, path, params, body, stream, files, raw_body)
#    1018                     params=params, data=body,
#    1019                     files = files,
# -> 1020                     stream = stream)
#    1021             http_res.raise_for_status()
#    1022             return http_res
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/Prophet/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
