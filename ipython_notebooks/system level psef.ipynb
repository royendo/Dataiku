# %%
# %pylab inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a6e0d37a4680> in <module>
# ----> 1 get_ipython().run_line_magic('pylab', 'inline')
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/sh/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# <decorator-gen-109> in pylab(self, line)
#
# ~/Library/DataScienceStudio/dss_home/code-envs/python/sh/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...

# %%
import sh

# %%
for x in sh.grep(sh.ps("-ef"), 'dataiku'):
    print(x)
    print()
# Out:
#   502  1604  1601   0  1:00PM ??         0:03.20 /Users/rendo/Library/DataScienceStudio/dss_home/pyenv/bin/python /opt/dataiku/install/dataiku-dss-9.0.3-osx/dku-jupyter/dkulauncher.py --config=/opt/dataiku/install/dataiku-dss-9.0.3-osx/dku-jupyter/dataiku_jupyter_config.py --notebook-dir=/Users/rendo/Library/DataScienceStudio/dss_home/config/ipython_notebooks --ip=127.0.0.1 --port=11202 --no-browser --port-retries=0
#
#
#   502  1605  1601   0  1:00PM ??         0:00.03 nginx: master process /opt/dataiku/install/dataiku-dss-9.0.3-osx/tools/sbin/nginx -c /Users/rendo/Library/DataScienceStudio/dss_home/install-support/nginx.conf
#
#
# ...

# %%
# !ps -ef | grep dataiku | awk {'print $2, $10'}
# Out:
# awk: syntax error at source line 1
#  context is
# 	 >>> print <<<
# awk: bailing out at source line 1
