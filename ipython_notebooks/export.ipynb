# %%
# %pylab inline

# %%
import dataiku
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(50,2), columns = ['test','columns'])

# %%
df
# Out:
#         test   columns
# 0   0.546595  0.179557
# 1   0.630106  0.355439
# 2   0.220781  0.192093
# 3   0.724259  0.394182
# 4   0.147773  0.687135
# 5   0.828540  0.732770
# 6   0.693253  0.833590
# 7   0.756669  0.180898
# 8   0.230196  0.119355
# 9   0.939416  0.604725
# 10  0.394346  0.903792
# 11  0.214920  0.981539
# 12  0.079944  0.448322
# 13  0.869045  0.913737
# 14  0.807689  0.922993
# 15  0.102390  0.380379
# 16  0.750964  0.604201
# 17  0.657134  0.308993
# 18  0.535512  0.751233
# 19  0.082493  0.404578
# 20  0.630102  0.458168
# 21  0.859209  0.803282
# 22  0.535783  0.609020
# 23  0.242470  0.807655
# 24  0.606429  0.545309
# 25  0.167495  0.004416
# 26  0.556605  0.612865
# 27  0.931437  0.832441
# 28  0.378504  0.469240
# 29  0.828794  0.099672
# 30  0.132743  0.728966
# 31  0.982936  0.979539
# 32  0.768096  0.753852
# 33  0.054216  0.642335
# 34  0.732425  0.717326
# 35  0.441139  0.178786
# 36  0.862737  0.174978
# 37  0.569623  0.498282
# 38  0.695651  0.311673
# ...
